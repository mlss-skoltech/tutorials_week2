# %% [markdown]
# Graph Convolutional Network
# ====================================
#
# This is a gentle introduction to implement Graph Convolutional
# Networks (Kipf & Welling et al., [Semi-Supervised Classification with Graph
# Convolutional Networks](https://arxiv.org/pdf/1609.02907.pdf)).
#
# <!-- ![GCN](gcn.png) -->
# <img src="gcn.png" align="center"/>

# %% [markdown]
# ## CORA dataset
# The [Cora dataset](https://relational.fit.cvut.cz/dataset/CORA) consists of __2708__ scientific publications classified into one of seven classes. The citation network consists of __5429__ links. Each publication in the dataset is described by a 0/1-valued word vector indicating the absence/presence of the corresponding word from the dictionary. The dictionary consists of __1433__ unique words.

# %% [markdown]
# <img src="https://www.researchgate.net/profile/Davide_Boscaini/publication/310953386/figure/fig1/AS:669401682563079@1536609206304/Predictions-obtained-applying-MoNet-over-the-Cora-dataset-Marker-fill-color-represents.png">

# %%
# !pip install -q --upgrade git+https://github.com/mlss-skoltech/tutorials_week2.git#subdirectory=graph_neural_networks

# %%
import pkg_resources

ZIP_PATH = pkg_resources.resource_filename('gnnutils', 'data/data.zip')
DATA_PATH = './data'

# !unzip -u {ZIP_PATH} -d ./
# Out:
# Archive:  /anaconda3/lib/python3.7/site-packages/gnnutils/data/data.zip

# %%
import os,sys,inspect
import os
import joblib
import tensorflow as tf
import numpy as np
import h5py
import scipy.sparse.linalg as la
import scipy.sparse as sp
import scipy
import time
import pickle

import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
# %matplotlib inline

import scipy.io as sio
from gnnutils import process_data

# %% [markdown]
# the Frobenius norm:
# $$\| A \|_F = \left( \sum_{i,j=1}^n | a_{ij} |^2 \right)^{1/2}$$.

# %%
def frobenius_norm(tensor):
    square_tensor = tf.square(tensor)
    tensor_sum = tf.reduce_sum(square_tensor)
    frobenius_norm = tf.sqrt(tensor_sum)
    return frobenius_norm

# %% [markdown]
# Helpful function to convert numpy array column ordered sparse representation to tensorflow sparse tensor format

# %%
def convert_coo_to_sparse_tensor(L):
    indices = np.column_stack((L.row, L.col))
    L = tf.SparseTensor(indices, L.data.astype('float32'), L.shape)
    L = tf.sparse_reorder(L)
    return L

# %%
class GCN:
    
    """
    The neural network model.
    """
     
    def __init__(self, A, X, Y, num_hidden_feat, learning_rate=5e-2, gamma=1e-3, idx_gpu = '/gpu:2'):
        
        self.num_hidden_feat = num_hidden_feat
        self.learning_rate = learning_rate
        self.gamma=gamma
        with tf.Graph().as_default() as g:
                self.graph = g
                
                with tf.device(idx_gpu):
                        #definition of constant matrices
                        self.A = convert_coo_to_sparse_tensor(A.tocoo())
                        self.X = tf.constant(X, dtype=tf.float32) 
                        self.Y = tf.constant(Y, dtype=tf.float32)
                        
                        self.W0 = tf.get_variable("W0", shape=[X.shape[1], self.num_hidden_feat], initializer=tf.contrib.layers.xavier_initializer())
                        self.W1 = tf.get_variable("W1", shape=[self.num_hidden_feat, Y.shape[1]], initializer=tf.contrib.layers.xavier_initializer())
                        
                        #placeholder definition
                        self.idx_nodes = tf.placeholder(tf.int32)
                        self.keep_prob = tf.placeholder(tf.float32)
                        
                        #model definition
                        self.l_input = tf.nn.dropout(self.X,  self.keep_prob)
                        
                        self.X0_tilde = tf.sparse_tensor_dense_matmul(self.A, self.l_input)
                        self.X0 = tf.matmul(self.X0_tilde, self.W0)
                        self.X0 = tf.nn.relu(self.X0)
                        self.X0 = tf.nn.dropout(self.X0,  self.keep_prob)
                        
                        self.X1_tilde = tf.sparse_tensor_dense_matmul(self.A, self.X0)
                        self.logits = tf.matmul(self.X1_tilde, self.W1)
                        
                        self.l_out = tf.gather(self.logits, self.idx_nodes)
                        self.c_Y = tf.gather(self.Y, self.idx_nodes)
                        
                        #loss function definition
                        self.l2_reg = tf.nn.l2_loss(self.W0)
                        self.data_loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=self.l_out, labels=self.c_Y)) 
                        self.loss = self.data_loss + self.gamma*self.l2_reg
                        
                        #solver definition
                        self.optimizer = tf.train.AdamOptimizer(learning_rate=self.learning_rate)
                        self.opt_step = self.optimizer.minimize(self.loss)
                        
                        #predictions and accuracy extraction
                        self.c_predictions = tf.argmax(tf.nn.softmax(self.l_out), 1)
                        self.accuracy = tf.contrib.metrics.accuracy(self.c_predictions, tf.argmax(self.c_Y, 1))
                        
                        #gradients computation
                        self.trainable_variables = tf.trainable_variables()
                        self.var_grad = tf.gradients(self.loss, tf.trainable_variables())
                        self.norm_grad = frobenius_norm(tf.concat([tf.reshape(g, [-1]) for g in self.var_grad], 0))
                        
                        #session creation
                        config = tf.ConfigProto(allow_soft_placement = True)
                        config.gpu_options.allow_growth = True
                        self.session = tf.Session(config=config)

                        #session initialization
                        init = tf.global_variables_initializer()
                        self.session.run(init)

# %% [markdown]
# We define hyperparameters of training procedure and load data using our utility library *process_data*.

# %%
#learning parameters and path dataset

num_total_iter_training = 3000
learning_rate = 1e-2
val_test_interval = 1
num_hidden_feat = 16
gamma = 5e-4

# %%
#dataset loading
A, X, Y, train_idx, val_idx, test_idx = process_data.load_data("cora", path_to_data=DATA_PATH)
X = process_data.preprocess_features(X)
# Out:
# (2708, 2708)
# (2708, 1433)

# %% [markdown]
# $$\mathbf{X}^{\prime} = \mathbf{\hat{D}}^{-1/2} \mathbf{\hat{A}}
#         \mathbf{\hat{D}}^{-1/2} \mathbf{X} \mathbf{\Theta}$$
#
# where $$\mathbf{\hat{A}} = \mathbf{A} + \mathbf{I}$$ denotes the
#     adjacency matrix with inserted self-loops and
#     $$\hat{D}_{ii} = \sum_{j=0} \hat{A}_{ij}$$ its diagonal degree matrix.

# %%
# compute GCN adj matrix
A_tilde = sp.csr_matrix(A)
A_tilde.setdiag(1)
D = A_tilde.sum(axis=1)

D_rows, D_cols = D.nonzero()
D_vals = [D[i,j] for i, j in zip(D_rows, D_cols)]
D_vals = np.reciprocal(np.sqrt(np.asarray(D_vals)))

D_inv_sqrt = sp.csr_matrix((D_vals, (range(len(D_vals)), range(len(D_vals)))))

A_tilde = D_inv_sqrt.dot(A_tilde).dot(D_inv_sqrt)
A_tilde = A_tilde.tocsr()
A_tilde.eliminate_zeros()
# Out:
# /home/fmonti/.Envs/venv36/lib/python3.6/site-packages/scipy/sparse/compressed.py:708: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self[i, j] = values

# %%
num_exp = 10 #number of times training GCN over the given dataset

list_all_acc = []
list_all_cost_val_avg  = []
list_all_data_cost_val_avg = []
list_all_acc_val_avg   = []
list_all_cost_test_avg = []
list_all_acc_test_avg  = []

num_done = 0
for seed in range(num_exp):
    GCNN = GCN(A_tilde, X, Y, num_hidden_feat, learning_rate=learning_rate, gamma=gamma)

    cost_train_avg      = []
    grad_norm_train_avg = []
    acc_train_avg       = []
    cost_test_avg       = []
    grad_norm_test_avg  = []
    acc_test_avg        = []
    cost_val_avg        = []
    data_cost_val_avg   = []
    acc_val_avg         = []
    iter_test           = []
    list_training_time = list()

    #Training code
    for i in range(num_total_iter_training):
        if (len(cost_train_avg) % val_test_interval) == 0:
            #Print last training performance
            if (len(cost_train_avg)>0):
                print("[TRN] epoch = %03i, cost = %3.2e, |grad| = %.2e, acc = %3.2e (%03.2fs)" % \
                (len(cost_train_avg), cost_train_avg[-1], grad_norm_train_avg[-1], acc_train_avg[-1], time.time() - tic))

            #Validate the model
            tic = time.time()
            
            feed_dict = {GCNN.idx_nodes: val_idx, GCNN.keep_prob:1.0}
            acc_val, cost_val, data_cost_val = GCNN.session.run([GCNN.accuracy, GCNN.loss, GCNN.data_loss], feed_dict)
            
            data_cost_val_avg.append(data_cost_val)
            cost_val_avg.append(cost_val)
            acc_val_avg.append(acc_val)
            print("[VAL] epoch = %03i, data_cost = %3.2e, cost = %3.2e, acc = %3.2e (%03.2fs)" % \
                (len(cost_train_avg), data_cost_val_avg[-1], cost_val_avg[-1], acc_val_avg[-1],  time.time() - tic))

            #Test the model
            tic = time.time()
            
            feed_dict = {GCNN.idx_nodes: test_idx, GCNN.keep_prob:1.0}
            acc_test, cost_test = GCNN.session.run([GCNN.accuracy, GCNN.loss], feed_dict)
            
            cost_test_avg.append(cost_test)
            acc_test_avg.append(acc_test)
            print("[TST] epoch = %03i, cost = %3.2e, acc = %3.2e (%03.2fs)" % \
                (len(cost_train_avg), cost_test_avg[-1], acc_test_avg[-1],  time.time() - tic))
            iter_test.append(len(cost_train_avg))

        tic = time.time()

        tic = time.time()
        feed_dict = {GCNN.idx_nodes: train_idx, GCNN.keep_prob: 0.5}
        
        _, current_training_loss, norm_grad, current_acc_training = GCNN.session.run([GCNN.opt_step, GCNN.loss, GCNN.norm_grad, GCNN.accuracy], feed_dict) 

        training_time = time.time() - tic   

        cost_train_avg.append(current_training_loss)
        grad_norm_train_avg.append(norm_grad)
        acc_train_avg.append(current_acc_training)

    #Compute and print statistics of the last realized experiment
    list_all_acc.append(100*(np.asarray(acc_test_avg)[np.asarray(data_cost_val_avg)==np.min(data_cost_val_avg)]))
    list_all_cost_val_avg.append(cost_val_avg)
    list_all_data_cost_val_avg.append(data_cost_val_avg)
    list_all_acc_val_avg.append(acc_val_avg)
    list_all_cost_test_avg.append(cost_test_avg)
    list_all_acc_test_avg.append(acc_test_avg)

    print('Num done: %d' % num_done)
    print('Max accuracy on test set achieved: %f%%' % np.max(np.asarray(acc_test_avg)*100))
    print('Max suggested accuracy: %f%%' % (100*(np.asarray(acc_test_avg)[np.asarray(data_cost_val_avg)==np.min(data_cost_val_avg)]),))
    print('Current mean: %f%%' % np.mean(list_all_acc))
    print('Current std: %f' % np.std(list_all_acc))

    num_done += 1
# Out:
# [VAL] epoch = 000, data_cost = 1.95e+00, cost = 1.95e+00, acc = 1.14e-01 (0.04s)
# [TST] epoch = 000, cost = 1.95e+00, acc = 9.80e-02 (0.04s)
# [TRN] epoch = 001, cost = 1.95e+00, |grad| = 1.45e-02, acc = 1.14e-01 (0.08s)
# [VAL] epoch = 001, data_cost = 1.94e+00, cost = 1.95e+00, acc = 2.46e-01 (0.00s)
# [TST] epoch = 001, cost = 1.95e+00, acc = 2.61e-01 (0.00s)
# [TRN] epoch = 002, cost = 1.95e+00, |grad| = 1.56e-02, acc = 3.21e-01 (0.01s)
# [VAL] epoch = 002, data_cost = 1.94e+00, cost = 1.95e+00, acc = 3.42e-01 (0.00s)
# [TST] epoch = 002, cost = 1.95e+00, acc = 4.02e-01 (0.00s)
# [TRN] epoch = 003, cost = 1.94e+00, |grad| = 1.95e-02, acc = 4.50e-01 (0.01s)
# [VAL] epoch = 003, data_cost = 1.94e+00, cost = 1.94e+00, acc = 3.92e-01 (0.00s)
# [TST] epoch = 003, cost = 1.94e+00, acc = 4.41e-01 (0.00s)
# [TRN] epoch = 004, cost = 1.93e+00, |grad| = 2.32e-02, acc = 4.93e-01 (0.01s)
# [VAL] epoch = 004, data_cost = 1.93e+00, cost = 1.94e+00, acc = 4.18e-01 (0.00s)
# [TST] epoch = 004, cost = 1.94e+00, acc = 4.72e-01 (0.00s)
# [TRN] epoch = 005, cost = 1.93e+00, |grad| = 2.25e-02, acc = 5.36e-01 (0.01s)
# [VAL] epoch = 005, data_cost = 1.93e+00, cost = 1.93e+00, acc = 4.82e-01 (0.00s)
# [TST] epoch = 005, cost = 1.93e+00, acc = 5.07e-01 (0.00s)
# [TRN] epoch = 006, cost = 1.92e+00, |grad| = 2.60e-02, acc = 6.50e-01 (0.01s)
# [VAL] epoch = 006, data_cost = 1.92e+00, cost = 1.93e+00, acc = 5.22e-01 (0.00s)
# [TST] epoch = 006, cost = 1.93e+00, acc = 5.53e-01 (0.00s)
# [TRN] epoch = 007, cost = 1.91e+00, |grad| = 2.60e-02, acc = 7.00e-01 (0.01s)
# [VAL] epoch = 007, data_cost = 1.92e+00, cost = 1.93e+00, acc = 5.64e-01 (0.00s)
# [TST] epoch = 007, cost = 1.92e+00, acc = 5.81e-01 (0.00s)
# [TRN] epoch = 008, cost = 1.90e+00, |grad| = 2.75e-02, acc = 6.79e-01 (0.01s)
# [VAL] epoch = 008, data_cost = 1.91e+00, cost = 1.92e+00, acc = 5.74e-01 (0.00s)
# [TST] epoch = 008, cost = 1.92e+00, acc = 5.95e-01 (0.00s)
# [TRN] epoch = 009, cost = 1.90e+00, |grad| = 2.91e-02, acc = 6.86e-01 (0.01s)
# [VAL] epoch = 009, data_cost = 1.91e+00, cost = 1.92e+00, acc = 5.90e-01 (0.00s)
# [TST] epoch = 009, cost = 1.92e+00, acc = 6.14e-01 (0.00s)
# [TRN] epoch = 010, cost = 1.89e+00, |grad| = 3.10e-02, acc = 7.43e-01 (0.01s)
# [VAL] epoch = 010, data_cost = 1.90e+00, cost = 1.92e+00, acc = 6.00e-01 (0.00s)
# [TST] epoch = 010, cost = 1.91e+00, acc = 6.23e-01 (0.00s)
# [TRN] epoch = 011, cost = 1.88e+00, |grad| = 3.39e-02, acc = 7.21e-01 (0.01s)
# [VAL] epoch = 011, data_cost = 1.90e+00, cost = 1.91e+00, acc = 6.08e-01 (0.00s)
# [TST] epoch = 011, cost = 1.91e+00, acc = 6.29e-01 (0.00s)
# [TRN] epoch = 012, cost = 1.87e+00, |grad| = 3.54e-02, acc = 7.71e-01 (0.01s)
# [VAL] epoch = 012, data_cost = 1.89e+00, cost = 1.91e+00, acc = 6.16e-01 (0.00s)
# [TST] epoch = 012, cost = 1.90e+00, acc = 6.31e-01 (0.00s)
# [TRN] epoch = 013, cost = 1.86e+00, |grad| = 3.77e-02, acc = 7.93e-01 (0.01s)
# [VAL] epoch = 013, data_cost = 1.88e+00, cost = 1.90e+00, acc = 6.18e-01 (0.00s)
# [TST] epoch = 013, cost = 1.90e+00, acc = 6.30e-01 (0.00s)
# [TRN] epoch = 014, cost = 1.85e+00, |grad| = 3.90e-02, acc = 7.29e-01 (0.01s)
# [VAL] epoch = 014, data_cost = 1.88e+00, cost = 1.90e+00, acc = 6.16e-01 (0.00s)
# [TST] epoch = 014, cost = 1.90e+00, acc = 6.36e-01 (0.00s)
# [TRN] epoch = 015, cost = 1.84e+00, |grad| = 4.21e-02, acc = 8.00e-01 (0.01s)
# [VAL] epoch = 015, data_cost = 1.87e+00, cost = 1.90e+00, acc = 6.18e-01 (0.00s)
# [TST] epoch = 015, cost = 1.89e+00, acc = 6.38e-01 (0.00s)
# [TRN] epoch = 016, cost = 1.83e+00, |grad| = 4.57e-02, acc = 8.50e-01 (0.01s)
# [VAL] epoch = 016, data_cost = 1.86e+00, cost = 1.89e+00, acc = 6.22e-01 (0.00s)
# [TST] epoch = 016, cost = 1.89e+00, acc = 6.40e-01 (0.00s)
# [TRN] epoch = 017, cost = 1.83e+00, |grad| = 4.60e-02, acc = 8.21e-01 (0.01s)
# [VAL] epoch = 017, data_cost = 1.86e+00, cost = 1.89e+00, acc = 6.24e-01 (0.00s)
# [TST] epoch = 017, cost = 1.88e+00, acc = 6.42e-01 (0.00s)
# [TRN] epoch = 018, cost = 1.82e+00, |grad| = 4.67e-02, acc = 7.57e-01 (0.01s)
# [VAL] epoch = 018, data_cost = 1.85e+00, cost = 1.88e+00, acc = 6.24e-01 (0.00s)
# [TST] epoch = 018, cost = 1.88e+00, acc = 6.45e-01 (0.00s)
# [TRN] epoch = 019, cost = 1.80e+00, |grad| = 5.10e-02, acc = 7.64e-01 (0.01s)
# [VAL] epoch = 019, data_cost = 1.84e+00, cost = 1.88e+00, acc = 6.28e-01 (0.00s)
# [TST] epoch = 019, cost = 1.87e+00, acc = 6.48e-01 (0.00s)
# [TRN] epoch = 020, cost = 1.81e+00, |grad| = 4.77e-02, acc = 7.86e-01 (0.01s)
# [VAL] epoch = 020, data_cost = 1.84e+00, cost = 1.87e+00, acc = 6.32e-01 (0.00s)
# [TST] epoch = 020, cost = 1.87e+00, acc = 6.50e-01 (0.00s)
# [TRN] epoch = 021, cost = 1.78e+00, |grad| = 5.38e-02, acc = 7.93e-01 (0.01s)
# [VAL] epoch = 021, data_cost = 1.83e+00, cost = 1.87e+00, acc = 6.36e-01 (0.00s)
# [TST] epoch = 021, cost = 1.86e+00, acc = 6.52e-01 (0.00s)
# [TRN] epoch = 022, cost = 1.78e+00, |grad| = 5.18e-02, acc = 7.86e-01 (0.01s)
# [VAL] epoch = 022, data_cost = 1.82e+00, cost = 1.86e+00, acc = 6.36e-01 (0.00s)
# [TST] epoch = 022, cost = 1.85e+00, acc = 6.54e-01 (0.00s)
# [TRN] epoch = 023, cost = 1.76e+00, |grad| = 5.72e-02, acc = 8.43e-01 (0.01s)
# [VAL] epoch = 023, data_cost = 1.81e+00, cost = 1.86e+00, acc = 6.42e-01 (0.00s)
# [TST] epoch = 023, cost = 1.85e+00, acc = 6.62e-01 (0.00s)
# [TRN] epoch = 024, cost = 1.74e+00, |grad| = 6.22e-02, acc = 8.36e-01 (0.01s)
# [VAL] epoch = 024, data_cost = 1.80e+00, cost = 1.85e+00, acc = 6.50e-01 (0.00s)
# [TST] epoch = 024, cost = 1.84e+00, acc = 6.71e-01 (0.00s)
# [TRN] epoch = 025, cost = 1.73e+00, |grad| = 6.16e-02, acc = 8.43e-01 (0.01s)
# [VAL] epoch = 025, data_cost = 1.79e+00, cost = 1.85e+00, acc = 6.58e-01 (0.00s)
# [TST] epoch = 025, cost = 1.84e+00, acc = 6.75e-01 (0.00s)
# [TRN] epoch = 026, cost = 1.72e+00, |grad| = 6.42e-02, acc = 8.36e-01 (0.01s)
# [VAL] epoch = 026, data_cost = 1.78e+00, cost = 1.84e+00, acc = 6.62e-01 (0.00s)
# [TST] epoch = 026, cost = 1.83e+00, acc = 6.78e-01 (0.00s)
# [TRN] epoch = 027, cost = 1.71e+00, |grad| = 6.51e-02, acc = 8.21e-01 (0.01s)
# [VAL] epoch = 027, data_cost = 1.77e+00, cost = 1.83e+00, acc = 6.72e-01 (0.00s)
# [TST] epoch = 027, cost = 1.82e+00, acc = 6.85e-01 (0.00s)
# [TRN] epoch = 028, cost = 1.68e+00, |grad| = 6.99e-02, acc = 8.43e-01 (0.01s)
# [VAL] epoch = 028, data_cost = 1.76e+00, cost = 1.83e+00, acc = 6.80e-01 (0.00s)
# [TST] epoch = 028, cost = 1.82e+00, acc = 6.92e-01 (0.00s)
# [TRN] epoch = 029, cost = 1.68e+00, |grad| = 6.75e-02, acc = 8.57e-01 (0.01s)
# [VAL] epoch = 029, data_cost = 1.75e+00, cost = 1.82e+00, acc = 6.84e-01 (0.00s)
# [TST] epoch = 029, cost = 1.81e+00, acc = 6.96e-01 (0.00s)
# [TRN] epoch = 030, cost = 1.67e+00, |grad| = 6.96e-02, acc = 8.43e-01 (0.01s)
# [VAL] epoch = 030, data_cost = 1.74e+00, cost = 1.81e+00, acc = 6.86e-01 (0.00s)
# [TST] epoch = 030, cost = 1.80e+00, acc = 7.00e-01 (0.00s)
# [TRN] epoch = 031, cost = 1.65e+00, |grad| = 7.14e-02, acc = 8.57e-01 (0.01s)
# [VAL] epoch = 031, data_cost = 1.73e+00, cost = 1.81e+00, acc = 6.92e-01 (0.00s)
# [TST] epoch = 031, cost = 1.79e+00, acc = 7.06e-01 (0.00s)
# [TRN] epoch = 032, cost = 1.64e+00, |grad| = 7.09e-02, acc = 8.29e-01 (0.01s)
# [VAL] epoch = 032, data_cost = 1.72e+00, cost = 1.80e+00, acc = 6.92e-01 (0.00s)
# [TST] epoch = 032, cost = 1.79e+00, acc = 7.09e-01 (0.00s)
# [TRN] epoch = 033, cost = 1.62e+00, |grad| = 7.27e-02, acc = 8.29e-01 (0.01s)
# [VAL] epoch = 033, data_cost = 1.71e+00, cost = 1.79e+00, acc = 6.94e-01 (0.00s)
# [TST] epoch = 033, cost = 1.78e+00, acc = 7.16e-01 (0.00s)
# [TRN] epoch = 034, cost = 1.61e+00, |grad| = 7.56e-02, acc = 8.57e-01 (0.01s)
# [VAL] epoch = 034, data_cost = 1.70e+00, cost = 1.78e+00, acc = 6.92e-01 (0.00s)
# [TST] epoch = 034, cost = 1.77e+00, acc = 7.21e-01 (0.00s)
# [TRN] epoch = 035, cost = 1.59e+00, |grad| = 7.65e-02, acc = 8.64e-01 (0.01s)
# [VAL] epoch = 035, data_cost = 1.69e+00, cost = 1.78e+00, acc = 6.96e-01 (0.00s)
# [TST] epoch = 035, cost = 1.76e+00, acc = 7.24e-01 (0.00s)
# [TRN] epoch = 036, cost = 1.60e+00, |grad| = 7.41e-02, acc = 8.43e-01 (0.01s)
# [VAL] epoch = 036, data_cost = 1.67e+00, cost = 1.77e+00, acc = 6.96e-01 (0.00s)
# [TST] epoch = 036, cost = 1.75e+00, acc = 7.31e-01 (0.00s)
# [TRN] epoch = 037, cost = 1.56e+00, |grad| = 8.10e-02, acc = 8.43e-01 (0.01s)
# [VAL] epoch = 037, data_cost = 1.66e+00, cost = 1.76e+00, acc = 7.00e-01 (0.00s)
# [TST] epoch = 037, cost = 1.75e+00, acc = 7.27e-01 (0.00s)
# [TRN] epoch = 038, cost = 1.54e+00, |grad| = 8.15e-02, acc = 8.64e-01 (0.01s)
# [VAL] epoch = 038, data_cost = 1.65e+00, cost = 1.76e+00, acc = 7.08e-01 (0.00s)
# [TST] epoch = 038, cost = 1.74e+00, acc = 7.34e-01 (0.00s)
# [TRN] epoch = 039, cost = 1.54e+00, |grad| = 8.01e-02, acc = 8.71e-01 (0.01s)
# [VAL] epoch = 039, data_cost = 1.64e+00, cost = 1.75e+00, acc = 7.10e-01 (0.00s)
# [TST] epoch = 039, cost = 1.73e+00, acc = 7.39e-01 (0.00s)
# [TRN] epoch = 040, cost = 1.50e+00, |grad| = 8.35e-02, acc = 8.93e-01 (0.01s)
# [VAL] epoch = 040, data_cost = 1.63e+00, cost = 1.74e+00, acc = 7.14e-01 (0.00s)
# [TST] epoch = 040, cost = 1.72e+00, acc = 7.40e-01 (0.00s)
# [TRN] epoch = 041, cost = 1.49e+00, |grad| = 8.28e-02, acc = 8.93e-01 (0.01s)
# [VAL] epoch = 041, data_cost = 1.61e+00, cost = 1.73e+00, acc = 7.14e-01 (0.00s)
# [TST] epoch = 041, cost = 1.71e+00, acc = 7.42e-01 (0.00s)
# [TRN] epoch = 042, cost = 1.51e+00, |grad| = 8.07e-02, acc = 8.86e-01 (0.01s)
# [VAL] epoch = 042, data_cost = 1.60e+00, cost = 1.72e+00, acc = 7.20e-01 (0.00s)
# [TST] epoch = 042, cost = 1.70e+00, acc = 7.46e-01 (0.00s)
# [TRN] epoch = 043, cost = 1.48e+00, |grad| = 8.30e-02, acc = 8.64e-01 (0.01s)
# [VAL] epoch = 043, data_cost = 1.59e+00, cost = 1.71e+00, acc = 7.24e-01 (0.00s)
# [TST] epoch = 043, cost = 1.69e+00, acc = 7.51e-01 (0.00s)
# [TRN] epoch = 044, cost = 1.45e+00, |grad| = 8.59e-02, acc = 9.14e-01 (0.01s)
# [VAL] epoch = 044, data_cost = 1.57e+00, cost = 1.70e+00, acc = 7.28e-01 (0.00s)
# [TST] epoch = 044, cost = 1.68e+00, acc = 7.58e-01 (0.00s)
# [TRN] epoch = 045, cost = 1.42e+00, |grad| = 8.68e-02, acc = 8.93e-01 (0.01s)
# [VAL] epoch = 045, data_cost = 1.56e+00, cost = 1.70e+00, acc = 7.30e-01 (0.00s)
# [TST] epoch = 045, cost = 1.67e+00, acc = 7.63e-01 (0.00s)
# [TRN] epoch = 046, cost = 1.44e+00, |grad| = 8.31e-02, acc = 9.00e-01 (0.01s)
# [VAL] epoch = 046, data_cost = 1.55e+00, cost = 1.69e+00, acc = 7.32e-01 (0.00s)
# [TST] epoch = 046, cost = 1.67e+00, acc = 7.65e-01 (0.00s)
# [TRN] epoch = 047, cost = 1.39e+00, |grad| = 8.54e-02, acc = 8.64e-01 (0.01s)
# [VAL] epoch = 047, data_cost = 1.53e+00, cost = 1.68e+00, acc = 7.34e-01 (0.00s)
# [TST] epoch = 047, cost = 1.66e+00, acc = 7.65e-01 (0.00s)
# [TRN] epoch = 048, cost = 1.38e+00, |grad| = 8.73e-02, acc = 8.86e-01 (0.01s)
# [VAL] epoch = 048, data_cost = 1.52e+00, cost = 1.67e+00, acc = 7.36e-01 (0.00s)
# [TST] epoch = 048, cost = 1.65e+00, acc = 7.68e-01 (0.00s)
# [TRN] epoch = 049, cost = 1.36e+00, |grad| = 8.59e-02, acc = 9.07e-01 (0.01s)
# [VAL] epoch = 049, data_cost = 1.50e+00, cost = 1.66e+00, acc = 7.38e-01 (0.00s)
# [TST] epoch = 049, cost = 1.64e+00, acc = 7.71e-01 (0.00s)
# [TRN] epoch = 050, cost = 1.39e+00, |grad| = 8.50e-02, acc = 8.93e-01 (0.01s)
# [VAL] epoch = 050, data_cost = 1.49e+00, cost = 1.65e+00, acc = 7.40e-01 (0.00s)
# [TST] epoch = 050, cost = 1.63e+00, acc = 7.71e-01 (0.00s)
# [TRN] epoch = 051, cost = 1.35e+00, |grad| = 8.54e-02, acc = 8.64e-01 (0.01s)
# [VAL] epoch = 051, data_cost = 1.48e+00, cost = 1.64e+00, acc = 7.42e-01 (0.00s)
# [TST] epoch = 051, cost = 1.62e+00, acc = 7.72e-01 (0.00s)
# [TRN] epoch = 052, cost = 1.33e+00, |grad| = 8.49e-02, acc = 8.86e-01 (0.01s)
# [VAL] epoch = 052, data_cost = 1.47e+00, cost = 1.63e+00, acc = 7.44e-01 (0.00s)
# [TST] epoch = 052, cost = 1.61e+00, acc = 7.71e-01 (0.00s)
# [TRN] epoch = 053, cost = 1.34e+00, |grad| = 8.44e-02, acc = 9.14e-01 (0.01s)
# [VAL] epoch = 053, data_cost = 1.45e+00, cost = 1.63e+00, acc = 7.44e-01 (0.00s)
# [TST] epoch = 053, cost = 1.60e+00, acc = 7.71e-01 (0.00s)
# [TRN] epoch = 054, cost = 1.31e+00, |grad| = 8.46e-02, acc = 8.93e-01 (0.01s)
# [VAL] epoch = 054, data_cost = 1.44e+00, cost = 1.62e+00, acc = 7.46e-01 (0.00s)
# [TST] epoch = 054, cost = 1.59e+00, acc = 7.74e-01 (0.00s)
# [TRN] epoch = 055, cost = 1.32e+00, |grad| = 8.34e-02, acc = 9.29e-01 (0.01s)
# [VAL] epoch = 055, data_cost = 1.43e+00, cost = 1.61e+00, acc = 7.48e-01 (0.00s)
# [TST] epoch = 055, cost = 1.58e+00, acc = 7.73e-01 (0.00s)
# [TRN] epoch = 056, cost = 1.27e+00, |grad| = 8.61e-02, acc = 8.93e-01 (0.01s)
# [VAL] epoch = 056, data_cost = 1.41e+00, cost = 1.60e+00, acc = 7.52e-01 (0.00s)
# [TST] epoch = 056, cost = 1.57e+00, acc = 7.77e-01 (0.00s)
# [TRN] epoch = 057, cost = 1.25e+00, |grad| = 8.43e-02, acc = 9.14e-01 (0.01s)
# [VAL] epoch = 057, data_cost = 1.40e+00, cost = 1.59e+00, acc = 7.56e-01 (0.00s)
# [TST] epoch = 057, cost = 1.57e+00, acc = 7.80e-01 (0.00s)
# [TRN] epoch = 058, cost = 1.29e+00, |grad| = 8.21e-02, acc = 9.00e-01 (0.01s)
# [VAL] epoch = 058, data_cost = 1.39e+00, cost = 1.58e+00, acc = 7.58e-01 (0.00s)
# [TST] epoch = 058, cost = 1.56e+00, acc = 7.81e-01 (0.00s)
# [TRN] epoch = 059, cost = 1.23e+00, |grad| = 8.44e-02, acc = 9.00e-01 (0.01s)
# [VAL] epoch = 059, data_cost = 1.38e+00, cost = 1.58e+00, acc = 7.56e-01 (0.00s)
# [TST] epoch = 059, cost = 1.55e+00, acc = 7.84e-01 (0.00s)
# [TRN] epoch = 060, cost = 1.23e+00, |grad| = 8.35e-02, acc = 9.07e-01 (0.01s)
# [VAL] epoch = 060, data_cost = 1.36e+00, cost = 1.57e+00, acc = 7.56e-01 (0.00s)
# [TST] epoch = 060, cost = 1.54e+00, acc = 7.83e-01 (0.00s)
# [TRN] epoch = 061, cost = 1.21e+00, |grad| = 8.13e-02, acc = 9.07e-01 (0.01s)
# [VAL] epoch = 061, data_cost = 1.35e+00, cost = 1.56e+00, acc = 7.56e-01 (0.00s)
# [TST] epoch = 061, cost = 1.53e+00, acc = 7.85e-01 (0.00s)
# [TRN] epoch = 062, cost = 1.18e+00, |grad| = 8.09e-02, acc = 9.36e-01 (0.01s)
# [VAL] epoch = 062, data_cost = 1.34e+00, cost = 1.55e+00, acc = 7.60e-01 (0.00s)
# [TST] epoch = 062, cost = 1.52e+00, acc = 7.88e-01 (0.00s)
# [TRN] epoch = 063, cost = 1.21e+00, |grad| = 8.07e-02, acc = 9.07e-01 (0.01s)
# [VAL] epoch = 063, data_cost = 1.33e+00, cost = 1.54e+00, acc = 7.62e-01 (0.00s)
# [TST] epoch = 063, cost = 1.51e+00, acc = 7.89e-01 (0.00s)
# [TRN] epoch = 064, cost = 1.19e+00, |grad| = 8.02e-02, acc = 8.86e-01 (0.01s)
# [VAL] epoch = 064, data_cost = 1.32e+00, cost = 1.53e+00, acc = 7.66e-01 (0.00s)
# [TST] epoch = 064, cost = 1.50e+00, acc = 7.91e-01 (0.00s)
# [TRN] epoch = 065, cost = 1.17e+00, |grad| = 7.89e-02, acc = 9.07e-01 (0.01s)
# [VAL] epoch = 065, data_cost = 1.30e+00, cost = 1.53e+00, acc = 7.68e-01 (0.00s)
# [TST] epoch = 065, cost = 1.49e+00, acc = 7.94e-01 (0.00s)
# [TRN] epoch = 066, cost = 1.16e+00, |grad| = 8.00e-02, acc = 9.21e-01 (0.01s)
# [VAL] epoch = 066, data_cost = 1.29e+00, cost = 1.52e+00, acc = 7.72e-01 (0.00s)
# [TST] epoch = 066, cost = 1.49e+00, acc = 7.95e-01 (0.00s)
# [TRN] epoch = 067, cost = 1.14e+00, |grad| = 7.57e-02, acc = 8.86e-01 (0.01s)
# [VAL] epoch = 067, data_cost = 1.28e+00, cost = 1.51e+00, acc = 7.74e-01 (0.00s)
# [TST] epoch = 067, cost = 1.48e+00, acc = 7.97e-01 (0.00s)
# [TRN] epoch = 068, cost = 1.13e+00, |grad| = 7.66e-02, acc = 9.07e-01 (0.01s)
# [VAL] epoch = 068, data_cost = 1.27e+00, cost = 1.50e+00, acc = 7.74e-01 (0.00s)
# [TST] epoch = 068, cost = 1.47e+00, acc = 7.99e-01 (0.00s)
# [TRN] epoch = 069, cost = 1.16e+00, |grad| = 7.47e-02, acc = 8.86e-01 (0.01s)
# [VAL] epoch = 069, data_cost = 1.26e+00, cost = 1.49e+00, acc = 7.74e-01 (0.00s)
# [TST] epoch = 069, cost = 1.46e+00, acc = 7.98e-01 (0.00s)
# [TRN] epoch = 070, cost = 1.13e+00, |grad| = 7.54e-02, acc = 8.86e-01 (0.01s)
# [VAL] epoch = 070, data_cost = 1.25e+00, cost = 1.48e+00, acc = 7.72e-01 (0.00s)
# [TST] epoch = 070, cost = 1.45e+00, acc = 7.98e-01 (0.00s)
# [TRN] epoch = 071, cost = 1.11e+00, |grad| = 7.33e-02, acc = 8.93e-01 (0.01s)
# [VAL] epoch = 071, data_cost = 1.24e+00, cost = 1.48e+00, acc = 7.70e-01 (0.00s)
# [TST] epoch = 071, cost = 1.44e+00, acc = 7.97e-01 (0.00s)
# [TRN] epoch = 072, cost = 1.14e+00, |grad| = 7.34e-02, acc = 8.64e-01 (0.01s)
# [VAL] epoch = 072, data_cost = 1.23e+00, cost = 1.47e+00, acc = 7.74e-01 (0.00s)
# [TST] epoch = 072, cost = 1.44e+00, acc = 7.97e-01 (0.00s)
# [TRN] epoch = 073, cost = 1.16e+00, |grad| = 7.69e-02, acc = 9.14e-01 (0.01s)
# [VAL] epoch = 073, data_cost = 1.22e+00, cost = 1.46e+00, acc = 7.74e-01 (0.00s)
# [TST] epoch = 073, cost = 1.43e+00, acc = 7.97e-01 (0.00s)
# [TRN] epoch = 074, cost = 1.11e+00, |grad| = 7.37e-02, acc = 9.00e-01 (0.01s)
# [VAL] epoch = 074, data_cost = 1.21e+00, cost = 1.45e+00, acc = 7.76e-01 (0.00s)
# [TST] epoch = 074, cost = 1.42e+00, acc = 8.00e-01 (0.00s)
# [TRN] epoch = 075, cost = 1.07e+00, |grad| = 7.78e-02, acc = 9.36e-01 (0.01s)
# [VAL] epoch = 075, data_cost = 1.20e+00, cost = 1.45e+00, acc = 7.76e-01 (0.00s)
# [TST] epoch = 075, cost = 1.41e+00, acc = 8.00e-01 (0.00s)
# [TRN] epoch = 076, cost = 1.08e+00, |grad| = 7.41e-02, acc = 9.00e-01 (0.01s)
# [VAL] epoch = 076, data_cost = 1.19e+00, cost = 1.44e+00, acc = 7.76e-01 (0.00s)
# [TST] epoch = 076, cost = 1.41e+00, acc = 8.02e-01 (0.00s)
# [TRN] epoch = 077, cost = 1.04e+00, |grad| = 7.40e-02, acc = 9.36e-01 (0.01s)
# [VAL] epoch = 077, data_cost = 1.18e+00, cost = 1.43e+00, acc = 7.76e-01 (0.00s)
# [TST] epoch = 077, cost = 1.40e+00, acc = 8.01e-01 (0.00s)
# [TRN] epoch = 078, cost = 1.06e+00, |grad| = 7.09e-02, acc = 9.00e-01 (0.01s)
# [VAL] epoch = 078, data_cost = 1.17e+00, cost = 1.43e+00, acc = 7.76e-01 (0.00s)
# [TST] epoch = 078, cost = 1.39e+00, acc = 8.03e-01 (0.00s)
# [TRN] epoch = 079, cost = 1.05e+00, |grad| = 7.27e-02, acc = 9.29e-01 (0.01s)
# [VAL] epoch = 079, data_cost = 1.16e+00, cost = 1.42e+00, acc = 7.78e-01 (0.00s)
# [TST] epoch = 079, cost = 1.38e+00, acc = 8.03e-01 (0.00s)
# [TRN] epoch = 080, cost = 1.02e+00, |grad| = 7.18e-02, acc = 9.21e-01 (0.01s)
# [VAL] epoch = 080, data_cost = 1.15e+00, cost = 1.41e+00, acc = 7.80e-01 (0.00s)
# [TST] epoch = 080, cost = 1.38e+00, acc = 8.04e-01 (0.00s)
# [TRN] epoch = 081, cost = 1.03e+00, |grad| = 6.89e-02, acc = 8.86e-01 (0.01s)
# [VAL] epoch = 081, data_cost = 1.14e+00, cost = 1.41e+00, acc = 7.80e-01 (0.00s)
# [TST] epoch = 081, cost = 1.37e+00, acc = 8.05e-01 (0.00s)
# [TRN] epoch = 082, cost = 1.01e+00, |grad| = 6.80e-02, acc = 9.07e-01 (0.01s)
# [VAL] epoch = 082, data_cost = 1.13e+00, cost = 1.40e+00, acc = 7.80e-01 (0.00s)
# [TST] epoch = 082, cost = 1.36e+00, acc = 8.06e-01 (0.00s)
# [TRN] epoch = 083, cost = 9.53e-01, |grad| = 6.88e-02, acc = 9.43e-01 (0.01s)
# [VAL] epoch = 083, data_cost = 1.13e+00, cost = 1.39e+00, acc = 7.80e-01 (0.00s)
# [TST] epoch = 083, cost = 1.36e+00, acc = 8.06e-01 (0.00s)
# [TRN] epoch = 084, cost = 1.03e+00, |grad| = 6.85e-02, acc = 8.93e-01 (0.01s)
# [VAL] epoch = 084, data_cost = 1.12e+00, cost = 1.39e+00, acc = 7.82e-01 (0.00s)
# [TST] epoch = 084, cost = 1.35e+00, acc = 8.04e-01 (0.00s)
# [TRN] epoch = 085, cost = 9.65e-01, |grad| = 6.69e-02, acc = 9.29e-01 (0.01s)
# [VAL] epoch = 085, data_cost = 1.11e+00, cost = 1.38e+00, acc = 7.82e-01 (0.00s)
# [TST] epoch = 085, cost = 1.34e+00, acc = 8.04e-01 (0.00s)
# [TRN] epoch = 086, cost = 1.02e+00, |grad| = 6.55e-02, acc = 9.29e-01 (0.01s)
# [VAL] epoch = 086, data_cost = 1.10e+00, cost = 1.38e+00, acc = 7.82e-01 (0.00s)
# [TST] epoch = 086, cost = 1.34e+00, acc = 8.05e-01 (0.00s)
# [TRN] epoch = 087, cost = 9.91e-01, |grad| = 6.56e-02, acc = 9.14e-01 (0.01s)
# [VAL] epoch = 087, data_cost = 1.10e+00, cost = 1.37e+00, acc = 7.84e-01 (0.00s)
# [TST] epoch = 087, cost = 1.33e+00, acc = 8.07e-01 (0.00s)
# [TRN] epoch = 088, cost = 9.60e-01, |grad| = 6.77e-02, acc = 9.29e-01 (0.01s)
# [VAL] epoch = 088, data_cost = 1.09e+00, cost = 1.36e+00, acc = 7.82e-01 (0.00s)
# [TST] epoch = 088, cost = 1.32e+00, acc = 8.09e-01 (0.00s)
# [TRN] epoch = 089, cost = 9.50e-01, |grad| = 6.54e-02, acc = 9.50e-01 (0.01s)
# [VAL] epoch = 089, data_cost = 1.08e+00, cost = 1.36e+00, acc = 7.84e-01 (0.00s)
# [TST] epoch = 089, cost = 1.32e+00, acc = 8.11e-01 (0.00s)
# [TRN] epoch = 090, cost = 9.23e-01, |grad| = 6.64e-02, acc = 9.36e-01 (0.01s)
# [VAL] epoch = 090, data_cost = 1.08e+00, cost = 1.35e+00, acc = 7.84e-01 (0.00s)
# [TST] epoch = 090, cost = 1.31e+00, acc = 8.11e-01 (0.00s)
# [TRN] epoch = 091, cost = 9.56e-01, |grad| = 6.52e-02, acc = 9.36e-01 (0.01s)
# [VAL] epoch = 091, data_cost = 1.07e+00, cost = 1.35e+00, acc = 7.84e-01 (0.00s)
# [TST] epoch = 091, cost = 1.31e+00, acc = 8.12e-01 (0.00s)
# [TRN] epoch = 092, cost = 9.03e-01, |grad| = 6.39e-02, acc = 9.36e-01 (0.01s)
# [VAL] epoch = 092, data_cost = 1.06e+00, cost = 1.34e+00, acc = 7.84e-01 (0.00s)
# [TST] epoch = 092, cost = 1.30e+00, acc = 8.13e-01 (0.00s)
# [TRN] epoch = 093, cost = 9.21e-01, |grad| = 6.43e-02, acc = 9.57e-01 (0.01s)
# [VAL] epoch = 093, data_cost = 1.06e+00, cost = 1.34e+00, acc = 7.84e-01 (0.00s)
# [TST] epoch = 093, cost = 1.30e+00, acc = 8.13e-01 (0.00s)
# [TRN] epoch = 094, cost = 9.05e-01, |grad| = 6.46e-02, acc = 9.43e-01 (0.01s)
# [VAL] epoch = 094, data_cost = 1.05e+00, cost = 1.33e+00, acc = 7.86e-01 (0.00s)
# [TST] epoch = 094, cost = 1.29e+00, acc = 8.14e-01 (0.00s)
# [TRN] epoch = 095, cost = 9.46e-01, |grad| = 6.21e-02, acc = 9.00e-01 (0.01s)
# [VAL] epoch = 095, data_cost = 1.05e+00, cost = 1.32e+00, acc = 7.86e-01 (0.00s)
# [TST] epoch = 095, cost = 1.28e+00, acc = 8.15e-01 (0.00s)
# [TRN] epoch = 096, cost = 9.14e-01, |grad| = 6.18e-02, acc = 9.29e-01 (0.01s)
# [VAL] epoch = 096, data_cost = 1.04e+00, cost = 1.32e+00, acc = 7.86e-01 (0.00s)
# [TST] epoch = 096, cost = 1.28e+00, acc = 8.14e-01 (0.00s)
# [TRN] epoch = 097, cost = 8.62e-01, |grad| = 6.00e-02, acc = 9.57e-01 (0.01s)
# [VAL] epoch = 097, data_cost = 1.03e+00, cost = 1.32e+00, acc = 7.84e-01 (0.00s)
# [TST] epoch = 097, cost = 1.27e+00, acc = 8.14e-01 (0.00s)
# [TRN] epoch = 098, cost = 8.94e-01, |grad| = 6.18e-02, acc = 9.14e-01 (0.01s)
# [VAL] epoch = 098, data_cost = 1.03e+00, cost = 1.31e+00, acc = 7.84e-01 (0.00s)
# [TST] epoch = 098, cost = 1.27e+00, acc = 8.12e-01 (0.00s)
# [TRN] epoch = 099, cost = 9.24e-01, |grad| = 6.03e-02, acc = 9.21e-01 (0.01s)
# [VAL] epoch = 099, data_cost = 1.02e+00, cost = 1.31e+00, acc = 7.82e-01 (0.00s)
# [TST] epoch = 099, cost = 1.26e+00, acc = 8.12e-01 (0.00s)
# [TRN] epoch = 100, cost = 8.85e-01, |grad| = 5.95e-02, acc = 9.36e-01 (0.01s)
# [VAL] epoch = 100, data_cost = 1.02e+00, cost = 1.30e+00, acc = 7.80e-01 (0.00s)
# [TST] epoch = 100, cost = 1.26e+00, acc = 8.12e-01 (0.00s)
# [TRN] epoch = 101, cost = 8.84e-01, |grad| = 5.97e-02, acc = 9.50e-01 (0.01s)
# [VAL] epoch = 101, data_cost = 1.01e+00, cost = 1.30e+00, acc = 7.80e-01 (0.00s)
# [TST] epoch = 101, cost = 1.25e+00, acc = 8.13e-01 (0.00s)
# [TRN] epoch = 102, cost = 9.05e-01, |grad| = 6.16e-02, acc = 9.71e-01 (0.01s)
# [VAL] epoch = 102, data_cost = 1.01e+00, cost = 1.29e+00, acc = 7.80e-01 (0.00s)
# [TST] epoch = 102, cost = 1.25e+00, acc = 8.13e-01 (0.00s)
# [TRN] epoch = 103, cost = 8.80e-01, |grad| = 5.78e-02, acc = 9.36e-01 (0.01s)
# [VAL] epoch = 103, data_cost = 1.01e+00, cost = 1.29e+00, acc = 7.82e-01 (0.00s)
# [TST] epoch = 103, cost = 1.25e+00, acc = 8.12e-01 (0.00s)
# [TRN] epoch = 104, cost = 9.09e-01, |grad| = 6.03e-02, acc = 9.29e-01 (0.01s)
# [VAL] epoch = 104, data_cost = 1.00e+00, cost = 1.29e+00, acc = 7.82e-01 (0.00s)
# [TST] epoch = 104, cost = 1.24e+00, acc = 8.12e-01 (0.00s)
# [TRN] epoch = 105, cost = 8.68e-01, |grad| = 5.80e-02, acc = 9.43e-01 (0.01s)
# [VAL] epoch = 105, data_cost = 1.00e+00, cost = 1.28e+00, acc = 7.82e-01 (0.00s)
# [TST] epoch = 105, cost = 1.24e+00, acc = 8.11e-01 (0.00s)
# [TRN] epoch = 106, cost = 9.05e-01, |grad| = 5.81e-02, acc = 9.14e-01 (0.01s)
# [VAL] epoch = 106, data_cost = 9.97e-01, cost = 1.28e+00, acc = 7.80e-01 (0.00s)
# [TST] epoch = 106, cost = 1.24e+00, acc = 8.07e-01 (0.00s)
# [TRN] epoch = 107, cost = 8.71e-01, |grad| = 5.60e-02, acc = 9.50e-01 (0.01s)
# [VAL] epoch = 107, data_cost = 9.94e-01, cost = 1.28e+00, acc = 7.80e-01 (0.00s)
# [TST] epoch = 107, cost = 1.23e+00, acc = 8.09e-01 (0.00s)
# [TRN] epoch = 108, cost = 8.51e-01, |grad| = 5.70e-02, acc = 9.21e-01 (0.01s)
# [VAL] epoch = 108, data_cost = 9.91e-01, cost = 1.27e+00, acc = 7.80e-01 (0.00s)
# [TST] epoch = 108, cost = 1.23e+00, acc = 8.09e-01 (0.00s)
# [TRN] epoch = 109, cost = 7.90e-01, |grad| = 5.53e-02, acc = 9.57e-01 (0.01s)
# [VAL] epoch = 109, data_cost = 9.88e-01, cost = 1.27e+00, acc = 7.80e-01 (0.00s)
# [TST] epoch = 109, cost = 1.23e+00, acc = 8.08e-01 (0.00s)
# [TRN] epoch = 110, cost = 8.22e-01, |grad| = 5.37e-02, acc = 9.57e-01 (0.01s)
# [VAL] epoch = 110, data_cost = 9.85e-01, cost = 1.27e+00, acc = 7.80e-01 (0.00s)
# [TST] epoch = 110, cost = 1.22e+00, acc = 8.08e-01 (0.01s)
# [TRN] epoch = 111, cost = 8.31e-01, |grad| = 5.40e-02, acc = 9.07e-01 (0.01s)
# [VAL] epoch = 111, data_cost = 9.82e-01, cost = 1.27e+00, acc = 7.82e-01 (0.00s)
# [TST] epoch = 111, cost = 1.22e+00, acc = 8.07e-01 (0.00s)
# [TRN] epoch = 112, cost = 8.26e-01, |grad| = 5.57e-02, acc = 9.57e-01 (0.01s)
# [VAL] epoch = 112, data_cost = 9.79e-01, cost = 1.26e+00, acc = 7.80e-01 (0.00s)
# [TST] epoch = 112, cost = 1.22e+00, acc = 8.07e-01 (0.00s)
# [TRN] epoch = 113, cost = 8.07e-01, |grad| = 5.36e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 113, data_cost = 9.76e-01, cost = 1.26e+00, acc = 7.80e-01 (0.00s)
# [TST] epoch = 113, cost = 1.21e+00, acc = 8.05e-01 (0.00s)
# [TRN] epoch = 114, cost = 8.31e-01, |grad| = 5.79e-02, acc = 9.50e-01 (0.01s)
# [VAL] epoch = 114, data_cost = 9.72e-01, cost = 1.26e+00, acc = 7.80e-01 (0.00s)
# [TST] epoch = 114, cost = 1.21e+00, acc = 8.06e-01 (0.00s)
# [TRN] epoch = 115, cost = 7.88e-01, |grad| = 5.16e-02, acc = 9.43e-01 (0.01s)
# [VAL] epoch = 115, data_cost = 9.68e-01, cost = 1.25e+00, acc = 7.80e-01 (0.00s)
# [TST] epoch = 115, cost = 1.20e+00, acc = 8.04e-01 (0.00s)
# [TRN] epoch = 116, cost = 8.30e-01, |grad| = 5.47e-02, acc = 9.43e-01 (0.01s)
# [VAL] epoch = 116, data_cost = 9.64e-01, cost = 1.25e+00, acc = 7.82e-01 (0.00s)
# [TST] epoch = 116, cost = 1.20e+00, acc = 8.07e-01 (0.00s)
# [TRN] epoch = 117, cost = 7.79e-01, |grad| = 5.40e-02, acc = 9.36e-01 (0.01s)
# [VAL] epoch = 117, data_cost = 9.59e-01, cost = 1.24e+00, acc = 7.84e-01 (0.00s)
# [TST] epoch = 117, cost = 1.20e+00, acc = 8.08e-01 (0.00s)
# [TRN] epoch = 118, cost = 8.00e-01, |grad| = 5.30e-02, acc = 9.71e-01 (0.01s)
# [VAL] epoch = 118, data_cost = 9.54e-01, cost = 1.24e+00, acc = 7.84e-01 (0.00s)
# [TST] epoch = 118, cost = 1.19e+00, acc = 8.12e-01 (0.00s)
# [TRN] epoch = 119, cost = 7.95e-01, |grad| = 5.06e-02, acc = 9.57e-01 (0.01s)
# [VAL] epoch = 119, data_cost = 9.50e-01, cost = 1.23e+00, acc = 7.84e-01 (0.00s)
# [TST] epoch = 119, cost = 1.19e+00, acc = 8.10e-01 (0.00s)
# [TRN] epoch = 120, cost = 7.87e-01, |grad| = 5.30e-02, acc = 9.57e-01 (0.01s)
# [VAL] epoch = 120, data_cost = 9.45e-01, cost = 1.23e+00, acc = 7.84e-01 (0.00s)
# [TST] epoch = 120, cost = 1.18e+00, acc = 8.11e-01 (0.00s)
# [TRN] epoch = 121, cost = 8.21e-01, |grad| = 5.35e-02, acc = 9.21e-01 (0.01s)
# [VAL] epoch = 121, data_cost = 9.41e-01, cost = 1.22e+00, acc = 7.86e-01 (0.00s)
# [TST] epoch = 121, cost = 1.18e+00, acc = 8.13e-01 (0.00s)
# [TRN] epoch = 122, cost = 8.00e-01, |grad| = 5.19e-02, acc = 9.50e-01 (0.01s)
# [VAL] epoch = 122, data_cost = 9.38e-01, cost = 1.22e+00, acc = 7.86e-01 (0.00s)
# [TST] epoch = 122, cost = 1.17e+00, acc = 8.13e-01 (0.00s)
# [TRN] epoch = 123, cost = 8.03e-01, |grad| = 5.24e-02, acc = 9.14e-01 (0.01s)
# [VAL] epoch = 123, data_cost = 9.35e-01, cost = 1.22e+00, acc = 7.86e-01 (0.00s)
# [TST] epoch = 123, cost = 1.17e+00, acc = 8.14e-01 (0.00s)
# [TRN] epoch = 124, cost = 7.66e-01, |grad| = 5.12e-02, acc = 9.36e-01 (0.01s)
# [VAL] epoch = 124, data_cost = 9.32e-01, cost = 1.21e+00, acc = 7.86e-01 (0.00s)
# [TST] epoch = 124, cost = 1.17e+00, acc = 8.15e-01 (0.00s)
# [TRN] epoch = 125, cost = 8.24e-01, |grad| = 5.28e-02, acc = 9.43e-01 (0.01s)
# [VAL] epoch = 125, data_cost = 9.29e-01, cost = 1.21e+00, acc = 7.84e-01 (0.00s)
# [TST] epoch = 125, cost = 1.16e+00, acc = 8.14e-01 (0.00s)
# [TRN] epoch = 126, cost = 7.91e-01, |grad| = 5.38e-02, acc = 9.21e-01 (0.01s)
# [VAL] epoch = 126, data_cost = 9.26e-01, cost = 1.21e+00, acc = 7.84e-01 (0.00s)
# [TST] epoch = 126, cost = 1.16e+00, acc = 8.12e-01 (0.00s)
# [TRN] epoch = 127, cost = 7.53e-01, |grad| = 4.96e-02, acc = 9.21e-01 (0.01s)
# [VAL] epoch = 127, data_cost = 9.24e-01, cost = 1.20e+00, acc = 7.84e-01 (0.00s)
# [TST] epoch = 127, cost = 1.16e+00, acc = 8.12e-01 (0.00s)
# [TRN] epoch = 128, cost = 7.73e-01, |grad| = 5.34e-02, acc = 9.43e-01 (0.01s)
# [VAL] epoch = 128, data_cost = 9.22e-01, cost = 1.20e+00, acc = 7.80e-01 (0.00s)
# [TST] epoch = 128, cost = 1.15e+00, acc = 8.11e-01 (0.00s)
# [TRN] epoch = 129, cost = 7.52e-01, |grad| = 5.16e-02, acc = 9.43e-01 (0.01s)
# [VAL] epoch = 129, data_cost = 9.21e-01, cost = 1.20e+00, acc = 7.80e-01 (0.00s)
# [TST] epoch = 129, cost = 1.15e+00, acc = 8.09e-01 (0.00s)
# [TRN] epoch = 130, cost = 7.79e-01, |grad| = 5.35e-02, acc = 9.50e-01 (0.01s)
# [VAL] epoch = 130, data_cost = 9.20e-01, cost = 1.20e+00, acc = 7.80e-01 (0.00s)
# [TST] epoch = 130, cost = 1.15e+00, acc = 8.08e-01 (0.00s)
# [TRN] epoch = 131, cost = 7.43e-01, |grad| = 4.93e-02, acc = 9.50e-01 (0.01s)
# [VAL] epoch = 131, data_cost = 9.18e-01, cost = 1.20e+00, acc = 7.82e-01 (0.00s)
# [TST] epoch = 131, cost = 1.15e+00, acc = 8.05e-01 (0.00s)
# [TRN] epoch = 132, cost = 7.52e-01, |grad| = 5.17e-02, acc = 9.50e-01 (0.01s)
# [VAL] epoch = 132, data_cost = 9.17e-01, cost = 1.19e+00, acc = 7.82e-01 (0.00s)
# [TST] epoch = 132, cost = 1.15e+00, acc = 8.04e-01 (0.00s)
# [TRN] epoch = 133, cost = 7.96e-01, |grad| = 5.00e-02, acc = 9.43e-01 (0.01s)
# [VAL] epoch = 133, data_cost = 9.16e-01, cost = 1.19e+00, acc = 7.82e-01 (0.00s)
# [TST] epoch = 133, cost = 1.15e+00, acc = 8.07e-01 (0.00s)
# [TRN] epoch = 134, cost = 7.10e-01, |grad| = 5.22e-02, acc = 9.71e-01 (0.01s)
# [VAL] epoch = 134, data_cost = 9.15e-01, cost = 1.19e+00, acc = 7.84e-01 (0.00s)
# [TST] epoch = 134, cost = 1.14e+00, acc = 8.05e-01 (0.00s)
# [TRN] epoch = 135, cost = 7.81e-01, |grad| = 5.75e-02, acc = 9.50e-01 (0.01s)
# [VAL] epoch = 135, data_cost = 9.13e-01, cost = 1.19e+00, acc = 7.84e-01 (0.00s)
# [TST] epoch = 135, cost = 1.14e+00, acc = 8.04e-01 (0.00s)
# [TRN] epoch = 136, cost = 7.97e-01, |grad| = 5.29e-02, acc = 9.43e-01 (0.01s)
# [VAL] epoch = 136, data_cost = 9.12e-01, cost = 1.19e+00, acc = 7.84e-01 (0.00s)
# [TST] epoch = 136, cost = 1.14e+00, acc = 8.02e-01 (0.00s)
# [TRN] epoch = 137, cost = 7.16e-01, |grad| = 4.79e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 137, data_cost = 9.11e-01, cost = 1.19e+00, acc = 7.84e-01 (0.00s)
# [TST] epoch = 137, cost = 1.14e+00, acc = 8.02e-01 (0.00s)
# [TRN] epoch = 138, cost = 7.37e-01, |grad| = 5.22e-02, acc = 9.14e-01 (0.01s)
# [VAL] epoch = 138, data_cost = 9.10e-01, cost = 1.19e+00, acc = 7.84e-01 (0.00s)
# [TST] epoch = 138, cost = 1.14e+00, acc = 8.01e-01 (0.00s)
# [TRN] epoch = 139, cost = 7.44e-01, |grad| = 4.88e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 139, data_cost = 9.09e-01, cost = 1.18e+00, acc = 7.82e-01 (0.00s)
# [TST] epoch = 139, cost = 1.14e+00, acc = 8.01e-01 (0.00s)
# [TRN] epoch = 140, cost = 7.32e-01, |grad| = 5.16e-02, acc = 9.50e-01 (0.01s)
# [VAL] epoch = 140, data_cost = 9.07e-01, cost = 1.18e+00, acc = 7.82e-01 (0.00s)
# [TST] epoch = 140, cost = 1.13e+00, acc = 8.02e-01 (0.00s)
# [TRN] epoch = 141, cost = 7.42e-01, |grad| = 5.09e-02, acc = 9.57e-01 (0.01s)
# [VAL] epoch = 141, data_cost = 9.05e-01, cost = 1.18e+00, acc = 7.82e-01 (0.00s)
# [TST] epoch = 141, cost = 1.13e+00, acc = 8.02e-01 (0.00s)
# [TRN] epoch = 142, cost = 7.70e-01, |grad| = 5.04e-02, acc = 9.36e-01 (0.01s)
# [VAL] epoch = 142, data_cost = 9.03e-01, cost = 1.18e+00, acc = 7.80e-01 (0.00s)
# [TST] epoch = 142, cost = 1.13e+00, acc = 8.03e-01 (0.00s)
# [TRN] epoch = 143, cost = 7.18e-01, |grad| = 4.74e-02, acc = 9.57e-01 (0.01s)
# [VAL] epoch = 143, data_cost = 9.01e-01, cost = 1.18e+00, acc = 7.82e-01 (0.00s)
# [TST] epoch = 143, cost = 1.13e+00, acc = 8.03e-01 (0.00s)
# [TRN] epoch = 144, cost = 7.12e-01, |grad| = 4.72e-02, acc = 9.71e-01 (0.01s)
# [VAL] epoch = 144, data_cost = 8.98e-01, cost = 1.17e+00, acc = 7.84e-01 (0.00s)
# [TST] epoch = 144, cost = 1.12e+00, acc = 8.03e-01 (0.00s)
# [TRN] epoch = 145, cost = 6.83e-01, |grad| = 4.75e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 145, data_cost = 8.94e-01, cost = 1.17e+00, acc = 7.84e-01 (0.00s)
# [TST] epoch = 145, cost = 1.12e+00, acc = 8.01e-01 (0.00s)
# [TRN] epoch = 146, cost = 7.41e-01, |grad| = 5.03e-02, acc = 9.43e-01 (0.01s)
# [VAL] epoch = 146, data_cost = 8.91e-01, cost = 1.17e+00, acc = 7.84e-01 (0.00s)
# [TST] epoch = 146, cost = 1.12e+00, acc = 8.02e-01 (0.00s)
# [TRN] epoch = 147, cost = 7.18e-01, |grad| = 4.66e-02, acc = 9.50e-01 (0.01s)
# [VAL] epoch = 147, data_cost = 8.88e-01, cost = 1.16e+00, acc = 7.84e-01 (0.00s)
# [TST] epoch = 147, cost = 1.11e+00, acc = 8.01e-01 (0.00s)
# [TRN] epoch = 148, cost = 6.98e-01, |grad| = 4.54e-02, acc = 9.57e-01 (0.01s)
# [VAL] epoch = 148, data_cost = 8.85e-01, cost = 1.16e+00, acc = 7.84e-01 (0.00s)
# [TST] epoch = 148, cost = 1.11e+00, acc = 8.02e-01 (0.00s)
# [TRN] epoch = 149, cost = 7.19e-01, |grad| = 4.92e-02, acc = 9.57e-01 (0.01s)
# [VAL] epoch = 149, data_cost = 8.83e-01, cost = 1.16e+00, acc = 7.84e-01 (0.00s)
# [TST] epoch = 149, cost = 1.11e+00, acc = 8.03e-01 (0.00s)
# [TRN] epoch = 150, cost = 6.89e-01, |grad| = 4.43e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 150, data_cost = 8.80e-01, cost = 1.15e+00, acc = 7.88e-01 (0.00s)
# [TST] epoch = 150, cost = 1.11e+00, acc = 8.04e-01 (0.00s)
# [TRN] epoch = 151, cost = 7.15e-01, |grad| = 4.73e-02, acc = 9.43e-01 (0.01s)
# [VAL] epoch = 151, data_cost = 8.77e-01, cost = 1.15e+00, acc = 7.88e-01 (0.00s)
# [TST] epoch = 151, cost = 1.10e+00, acc = 8.05e-01 (0.00s)
# [TRN] epoch = 152, cost = 7.36e-01, |grad| = 4.60e-02, acc = 9.36e-01 (0.01s)
# [VAL] epoch = 152, data_cost = 8.75e-01, cost = 1.15e+00, acc = 7.90e-01 (0.00s)
# [TST] epoch = 152, cost = 1.10e+00, acc = 8.05e-01 (0.00s)
# [TRN] epoch = 153, cost = 6.71e-01, |grad| = 4.67e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 153, data_cost = 8.72e-01, cost = 1.14e+00, acc = 7.90e-01 (0.00s)
# [TST] epoch = 153, cost = 1.10e+00, acc = 8.06e-01 (0.00s)
# [TRN] epoch = 154, cost = 7.14e-01, |grad| = 5.02e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 154, data_cost = 8.69e-01, cost = 1.14e+00, acc = 7.90e-01 (0.00s)
# [TST] epoch = 154, cost = 1.09e+00, acc = 8.07e-01 (0.00s)
# [TRN] epoch = 155, cost = 6.65e-01, |grad| = 4.49e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 155, data_cost = 8.67e-01, cost = 1.14e+00, acc = 7.90e-01 (0.00s)
# [TST] epoch = 155, cost = 1.09e+00, acc = 8.09e-01 (0.00s)
# [TRN] epoch = 156, cost = 6.78e-01, |grad| = 4.82e-02, acc = 9.71e-01 (0.01s)
# [VAL] epoch = 156, data_cost = 8.65e-01, cost = 1.14e+00, acc = 7.90e-01 (0.00s)
# [TST] epoch = 156, cost = 1.09e+00, acc = 8.10e-01 (0.00s)
# [TRN] epoch = 157, cost = 6.85e-01, |grad| = 4.64e-02, acc = 9.71e-01 (0.01s)
# [VAL] epoch = 157, data_cost = 8.63e-01, cost = 1.13e+00, acc = 7.90e-01 (0.00s)
# [TST] epoch = 157, cost = 1.09e+00, acc = 8.09e-01 (0.00s)
# [TRN] epoch = 158, cost = 7.04e-01, |grad| = 4.85e-02, acc = 9.36e-01 (0.01s)
# [VAL] epoch = 158, data_cost = 8.62e-01, cost = 1.13e+00, acc = 7.92e-01 (0.00s)
# [TST] epoch = 158, cost = 1.08e+00, acc = 8.09e-01 (0.00s)
# [TRN] epoch = 159, cost = 7.19e-01, |grad| = 4.67e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 159, data_cost = 8.60e-01, cost = 1.13e+00, acc = 7.92e-01 (0.00s)
# [TST] epoch = 159, cost = 1.08e+00, acc = 8.09e-01 (0.00s)
# [TRN] epoch = 160, cost = 7.08e-01, |grad| = 4.70e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 160, data_cost = 8.59e-01, cost = 1.13e+00, acc = 7.92e-01 (0.00s)
# [TST] epoch = 160, cost = 1.08e+00, acc = 8.07e-01 (0.00s)
# [TRN] epoch = 161, cost = 6.82e-01, |grad| = 4.56e-02, acc = 9.57e-01 (0.01s)
# [VAL] epoch = 161, data_cost = 8.58e-01, cost = 1.13e+00, acc = 7.92e-01 (0.00s)
# [TST] epoch = 161, cost = 1.08e+00, acc = 8.06e-01 (0.00s)
# [TRN] epoch = 162, cost = 6.44e-01, |grad| = 4.20e-02, acc = 9.71e-01 (0.01s)
# [VAL] epoch = 162, data_cost = 8.56e-01, cost = 1.13e+00, acc = 7.92e-01 (0.00s)
# [TST] epoch = 162, cost = 1.08e+00, acc = 8.07e-01 (0.00s)
# [TRN] epoch = 163, cost = 6.93e-01, |grad| = 4.59e-02, acc = 9.57e-01 (0.01s)
# [VAL] epoch = 163, data_cost = 8.55e-01, cost = 1.12e+00, acc = 7.92e-01 (0.00s)
# [TST] epoch = 163, cost = 1.07e+00, acc = 8.06e-01 (0.00s)
# [TRN] epoch = 164, cost = 6.99e-01, |grad| = 4.45e-02, acc = 9.50e-01 (0.01s)
# [VAL] epoch = 164, data_cost = 8.54e-01, cost = 1.12e+00, acc = 7.92e-01 (0.00s)
# [TST] epoch = 164, cost = 1.07e+00, acc = 8.06e-01 (0.00s)
# [TRN] epoch = 165, cost = 7.20e-01, |grad| = 4.70e-02, acc = 9.14e-01 (0.01s)
# [VAL] epoch = 165, data_cost = 8.55e-01, cost = 1.12e+00, acc = 7.90e-01 (0.00s)
# [TST] epoch = 165, cost = 1.07e+00, acc = 8.06e-01 (0.00s)
# [TRN] epoch = 166, cost = 6.46e-01, |grad| = 4.25e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 166, data_cost = 8.56e-01, cost = 1.12e+00, acc = 7.88e-01 (0.00s)
# [TST] epoch = 166, cost = 1.07e+00, acc = 8.05e-01 (0.00s)
# [TRN] epoch = 167, cost = 7.11e-01, |grad| = 4.63e-02, acc = 9.29e-01 (0.01s)
# [VAL] epoch = 167, data_cost = 8.56e-01, cost = 1.12e+00, acc = 7.88e-01 (0.00s)
# [TST] epoch = 167, cost = 1.07e+00, acc = 8.02e-01 (0.00s)
# [TRN] epoch = 168, cost = 6.99e-01, |grad| = 4.39e-02, acc = 9.29e-01 (0.01s)
# [VAL] epoch = 168, data_cost = 8.56e-01, cost = 1.12e+00, acc = 7.86e-01 (0.00s)
# [TST] epoch = 168, cost = 1.07e+00, acc = 8.02e-01 (0.00s)
# [TRN] epoch = 169, cost = 6.92e-01, |grad| = 4.70e-02, acc = 9.29e-01 (0.01s)
# [VAL] epoch = 169, data_cost = 8.56e-01, cost = 1.12e+00, acc = 7.86e-01 (0.00s)
# [TST] epoch = 169, cost = 1.07e+00, acc = 8.03e-01 (0.00s)
# [TRN] epoch = 170, cost = 7.07e-01, |grad| = 4.88e-02, acc = 9.07e-01 (0.01s)
# [VAL] epoch = 170, data_cost = 8.57e-01, cost = 1.12e+00, acc = 7.84e-01 (0.00s)
# [TST] epoch = 170, cost = 1.07e+00, acc = 8.01e-01 (0.00s)
# [TRN] epoch = 171, cost = 6.94e-01, |grad| = 4.38e-02, acc = 9.36e-01 (0.01s)
# [VAL] epoch = 171, data_cost = 8.57e-01, cost = 1.12e+00, acc = 7.84e-01 (0.00s)
# [TST] epoch = 171, cost = 1.07e+00, acc = 8.03e-01 (0.00s)
# [TRN] epoch = 172, cost = 6.40e-01, |grad| = 4.31e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 172, data_cost = 8.57e-01, cost = 1.12e+00, acc = 7.82e-01 (0.00s)
# [TST] epoch = 172, cost = 1.07e+00, acc = 8.03e-01 (0.00s)
# [TRN] epoch = 173, cost = 6.42e-01, |grad| = 4.54e-02, acc = 9.79e-01 (0.01s)
# [VAL] epoch = 173, data_cost = 8.57e-01, cost = 1.12e+00, acc = 7.82e-01 (0.00s)
# [TST] epoch = 173, cost = 1.07e+00, acc = 8.02e-01 (0.00s)
# [TRN] epoch = 174, cost = 6.68e-01, |grad| = 4.61e-02, acc = 9.43e-01 (0.01s)
# [VAL] epoch = 174, data_cost = 8.56e-01, cost = 1.12e+00, acc = 7.84e-01 (0.00s)
# [TST] epoch = 174, cost = 1.07e+00, acc = 8.02e-01 (0.00s)
# [TRN] epoch = 175, cost = 6.51e-01, |grad| = 4.23e-02, acc = 9.57e-01 (0.01s)
# [VAL] epoch = 175, data_cost = 8.57e-01, cost = 1.12e+00, acc = 7.84e-01 (0.00s)
# [TST] epoch = 175, cost = 1.07e+00, acc = 8.01e-01 (0.00s)
# [TRN] epoch = 176, cost = 6.53e-01, |grad| = 4.68e-02, acc = 9.86e-01 (0.01s)
# [VAL] epoch = 176, data_cost = 8.56e-01, cost = 1.12e+00, acc = 7.82e-01 (0.00s)
# [TST] epoch = 176, cost = 1.07e+00, acc = 8.00e-01 (0.00s)
# [TRN] epoch = 177, cost = 6.67e-01, |grad| = 4.68e-02, acc = 9.43e-01 (0.01s)
# [VAL] epoch = 177, data_cost = 8.54e-01, cost = 1.12e+00, acc = 7.82e-01 (0.00s)
# [TST] epoch = 177, cost = 1.06e+00, acc = 7.99e-01 (0.00s)
# [TRN] epoch = 178, cost = 6.51e-01, |grad| = 4.29e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 178, data_cost = 8.52e-01, cost = 1.12e+00, acc = 7.82e-01 (0.00s)
# [TST] epoch = 178, cost = 1.06e+00, acc = 8.00e-01 (0.00s)
# [TRN] epoch = 179, cost = 6.75e-01, |grad| = 4.55e-02, acc = 9.57e-01 (0.01s)
# [VAL] epoch = 179, data_cost = 8.51e-01, cost = 1.12e+00, acc = 7.80e-01 (0.00s)
# [TST] epoch = 179, cost = 1.06e+00, acc = 8.00e-01 (0.00s)
# [TRN] epoch = 180, cost = 6.69e-01, |grad| = 4.53e-02, acc = 9.50e-01 (0.01s)
# [VAL] epoch = 180, data_cost = 8.49e-01, cost = 1.11e+00, acc = 7.80e-01 (0.00s)
# [TST] epoch = 180, cost = 1.06e+00, acc = 8.01e-01 (0.00s)
# [TRN] epoch = 181, cost = 6.57e-01, |grad| = 4.74e-02, acc = 9.43e-01 (0.01s)
# [VAL] epoch = 181, data_cost = 8.47e-01, cost = 1.11e+00, acc = 7.84e-01 (0.00s)
# [TST] epoch = 181, cost = 1.06e+00, acc = 8.01e-01 (0.00s)
# [TRN] epoch = 182, cost = 6.72e-01, |grad| = 4.53e-02, acc = 9.57e-01 (0.01s)
# [VAL] epoch = 182, data_cost = 8.44e-01, cost = 1.11e+00, acc = 7.86e-01 (0.00s)
# [TST] epoch = 182, cost = 1.05e+00, acc = 8.02e-01 (0.00s)
# [TRN] epoch = 183, cost = 6.84e-01, |grad| = 4.48e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 183, data_cost = 8.41e-01, cost = 1.10e+00, acc = 7.88e-01 (0.00s)
# [TST] epoch = 183, cost = 1.05e+00, acc = 8.03e-01 (0.00s)
# [TRN] epoch = 184, cost = 6.08e-01, |grad| = 4.09e-02, acc = 9.71e-01 (0.01s)
# [VAL] epoch = 184, data_cost = 8.38e-01, cost = 1.10e+00, acc = 7.86e-01 (0.00s)
# [TST] epoch = 184, cost = 1.05e+00, acc = 8.04e-01 (0.00s)
# [TRN] epoch = 185, cost = 6.49e-01, |grad| = 4.15e-02, acc = 9.50e-01 (0.01s)
# [VAL] epoch = 185, data_cost = 8.35e-01, cost = 1.10e+00, acc = 7.84e-01 (0.00s)
# [TST] epoch = 185, cost = 1.04e+00, acc = 8.06e-01 (0.00s)
# [TRN] epoch = 186, cost = 6.48e-01, |grad| = 4.06e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 186, data_cost = 8.31e-01, cost = 1.09e+00, acc = 7.88e-01 (0.00s)
# [TST] epoch = 186, cost = 1.04e+00, acc = 8.05e-01 (0.00s)
# [TRN] epoch = 187, cost = 6.03e-01, |grad| = 3.92e-02, acc = 9.71e-01 (0.01s)
# [VAL] epoch = 187, data_cost = 8.29e-01, cost = 1.09e+00, acc = 7.88e-01 (0.00s)
# [TST] epoch = 187, cost = 1.04e+00, acc = 8.05e-01 (0.00s)
# [TRN] epoch = 188, cost = 6.52e-01, |grad| = 4.56e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 188, data_cost = 8.26e-01, cost = 1.09e+00, acc = 7.88e-01 (0.00s)
# [TST] epoch = 188, cost = 1.04e+00, acc = 8.06e-01 (0.00s)
# [TRN] epoch = 189, cost = 6.34e-01, |grad| = 4.35e-02, acc = 9.71e-01 (0.01s)
# [VAL] epoch = 189, data_cost = 8.24e-01, cost = 1.09e+00, acc = 7.86e-01 (0.00s)
# [TST] epoch = 189, cost = 1.03e+00, acc = 8.05e-01 (0.00s)
# [TRN] epoch = 190, cost = 6.23e-01, |grad| = 4.17e-02, acc = 9.79e-01 (0.01s)
# [VAL] epoch = 190, data_cost = 8.23e-01, cost = 1.08e+00, acc = 7.88e-01 (0.00s)
# [TST] epoch = 190, cost = 1.03e+00, acc = 8.06e-01 (0.00s)
# [TRN] epoch = 191, cost = 6.33e-01, |grad| = 4.58e-02, acc = 9.50e-01 (0.01s)
# [VAL] epoch = 191, data_cost = 8.22e-01, cost = 1.08e+00, acc = 7.90e-01 (0.00s)
# [TST] epoch = 191, cost = 1.03e+00, acc = 8.08e-01 (0.00s)
# [TRN] epoch = 192, cost = 6.30e-01, |grad| = 4.13e-02, acc = 9.71e-01 (0.01s)
# [VAL] epoch = 192, data_cost = 8.21e-01, cost = 1.08e+00, acc = 7.90e-01 (0.00s)
# [TST] epoch = 192, cost = 1.03e+00, acc = 8.08e-01 (0.00s)
# [TRN] epoch = 193, cost = 6.28e-01, |grad| = 3.91e-02, acc = 9.50e-01 (0.01s)
# [VAL] epoch = 193, data_cost = 8.20e-01, cost = 1.08e+00, acc = 7.90e-01 (0.00s)
# [TST] epoch = 193, cost = 1.03e+00, acc = 8.09e-01 (0.00s)
# [TRN] epoch = 194, cost = 6.16e-01, |grad| = 4.56e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 194, data_cost = 8.19e-01, cost = 1.08e+00, acc = 7.90e-01 (0.00s)
# [TST] epoch = 194, cost = 1.03e+00, acc = 8.10e-01 (0.00s)
# [TRN] epoch = 195, cost = 6.62e-01, |grad| = 4.33e-02, acc = 9.57e-01 (0.01s)
# [VAL] epoch = 195, data_cost = 8.18e-01, cost = 1.08e+00, acc = 7.90e-01 (0.00s)
# [TST] epoch = 195, cost = 1.03e+00, acc = 8.09e-01 (0.00s)
# [TRN] epoch = 196, cost = 6.13e-01, |grad| = 4.09e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 196, data_cost = 8.17e-01, cost = 1.08e+00, acc = 7.90e-01 (0.00s)
# [TST] epoch = 196, cost = 1.02e+00, acc = 8.09e-01 (0.00s)
# [TRN] epoch = 197, cost = 6.33e-01, |grad| = 4.29e-02, acc = 9.50e-01 (0.01s)
# [VAL] epoch = 197, data_cost = 8.18e-01, cost = 1.08e+00, acc = 7.90e-01 (0.00s)
# [TST] epoch = 197, cost = 1.02e+00, acc = 8.09e-01 (0.00s)
# [TRN] epoch = 198, cost = 6.67e-01, |grad| = 5.02e-02, acc = 9.36e-01 (0.01s)
# [VAL] epoch = 198, data_cost = 8.17e-01, cost = 1.07e+00, acc = 7.90e-01 (0.00s)
# [TST] epoch = 198, cost = 1.02e+00, acc = 8.09e-01 (0.00s)
# [TRN] epoch = 199, cost = 6.43e-01, |grad| = 4.56e-02, acc = 9.50e-01 (0.01s)
# [VAL] epoch = 199, data_cost = 8.17e-01, cost = 1.07e+00, acc = 7.90e-01 (0.00s)
# [TST] epoch = 199, cost = 1.02e+00, acc = 8.09e-01 (0.00s)
# [TRN] epoch = 200, cost = 6.21e-01, |grad| = 4.17e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 200, data_cost = 8.17e-01, cost = 1.07e+00, acc = 7.90e-01 (0.00s)
# [TST] epoch = 200, cost = 1.02e+00, acc = 8.08e-01 (0.00s)
# [TRN] epoch = 201, cost = 6.01e-01, |grad| = 4.44e-02, acc = 9.79e-01 (0.01s)
# [VAL] epoch = 201, data_cost = 8.14e-01, cost = 1.07e+00, acc = 7.90e-01 (0.00s)
# [TST] epoch = 201, cost = 1.02e+00, acc = 8.07e-01 (0.00s)
# [TRN] epoch = 202, cost = 6.27e-01, |grad| = 5.09e-02, acc = 9.57e-01 (0.01s)
# [VAL] epoch = 202, data_cost = 8.11e-01, cost = 1.07e+00, acc = 7.90e-01 (0.00s)
# [TST] epoch = 202, cost = 1.02e+00, acc = 8.06e-01 (0.00s)
# [TRN] epoch = 203, cost = 6.20e-01, |grad| = 4.72e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 203, data_cost = 8.08e-01, cost = 1.06e+00, acc = 7.88e-01 (0.00s)
# [TST] epoch = 203, cost = 1.01e+00, acc = 8.05e-01 (0.00s)
# [TRN] epoch = 204, cost = 6.44e-01, |grad| = 4.84e-02, acc = 9.36e-01 (0.01s)
# [VAL] epoch = 204, data_cost = 8.07e-01, cost = 1.06e+00, acc = 7.90e-01 (0.00s)
# [TST] epoch = 204, cost = 1.01e+00, acc = 8.06e-01 (0.00s)
# [TRN] epoch = 205, cost = 6.02e-01, |grad| = 4.11e-02, acc = 9.50e-01 (0.01s)
# [VAL] epoch = 205, data_cost = 8.05e-01, cost = 1.06e+00, acc = 7.90e-01 (0.00s)
# [TST] epoch = 205, cost = 1.01e+00, acc = 8.08e-01 (0.00s)
# [TRN] epoch = 206, cost = 6.35e-01, |grad| = 4.37e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 206, data_cost = 8.03e-01, cost = 1.06e+00, acc = 7.92e-01 (0.00s)
# [TST] epoch = 206, cost = 1.01e+00, acc = 8.08e-01 (0.00s)
# [TRN] epoch = 207, cost = 6.08e-01, |grad| = 4.16e-02, acc = 9.50e-01 (0.01s)
# [VAL] epoch = 207, data_cost = 8.02e-01, cost = 1.06e+00, acc = 7.88e-01 (0.00s)
# [TST] epoch = 207, cost = 1.01e+00, acc = 8.09e-01 (0.00s)
# [TRN] epoch = 208, cost = 6.35e-01, |grad| = 4.20e-02, acc = 9.57e-01 (0.01s)
# [VAL] epoch = 208, data_cost = 8.01e-01, cost = 1.06e+00, acc = 7.88e-01 (0.00s)
# [TST] epoch = 208, cost = 1.00e+00, acc = 8.07e-01 (0.00s)
# [TRN] epoch = 209, cost = 6.05e-01, |grad| = 4.12e-02, acc = 9.86e-01 (0.01s)
# [VAL] epoch = 209, data_cost = 8.01e-01, cost = 1.05e+00, acc = 7.90e-01 (0.00s)
# [TST] epoch = 209, cost = 1.00e+00, acc = 8.07e-01 (0.00s)
# [TRN] epoch = 210, cost = 6.54e-01, |grad| = 4.68e-02, acc = 9.57e-01 (0.01s)
# [VAL] epoch = 210, data_cost = 8.00e-01, cost = 1.05e+00, acc = 7.92e-01 (0.00s)
# [TST] epoch = 210, cost = 1.00e+00, acc = 8.09e-01 (0.00s)
# [TRN] epoch = 211, cost = 6.55e-01, |grad| = 4.47e-02, acc = 9.50e-01 (0.01s)
# [VAL] epoch = 211, data_cost = 8.00e-01, cost = 1.05e+00, acc = 7.94e-01 (0.00s)
# [TST] epoch = 211, cost = 1.00e+00, acc = 8.10e-01 (0.00s)
# [TRN] epoch = 212, cost = 6.16e-01, |grad| = 4.36e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 212, data_cost = 8.01e-01, cost = 1.05e+00, acc = 7.94e-01 (0.00s)
# [TST] epoch = 212, cost = 1.00e+00, acc = 8.10e-01 (0.00s)
# [TRN] epoch = 213, cost = 6.23e-01, |grad| = 4.80e-02, acc = 9.79e-01 (0.01s)
# [VAL] epoch = 213, data_cost = 8.01e-01, cost = 1.05e+00, acc = 7.90e-01 (0.00s)
# [TST] epoch = 213, cost = 1.00e+00, acc = 8.11e-01 (0.00s)
# [TRN] epoch = 214, cost = 6.14e-01, |grad| = 4.41e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 214, data_cost = 8.02e-01, cost = 1.06e+00, acc = 7.90e-01 (0.00s)
# [TST] epoch = 214, cost = 1.00e+00, acc = 8.10e-01 (0.00s)
# [TRN] epoch = 215, cost = 5.84e-01, |grad| = 3.96e-02, acc = 9.79e-01 (0.01s)
# [VAL] epoch = 215, data_cost = 8.03e-01, cost = 1.06e+00, acc = 7.90e-01 (0.00s)
# [TST] epoch = 215, cost = 1.00e+00, acc = 8.07e-01 (0.00s)
# [TRN] epoch = 216, cost = 5.80e-01, |grad| = 3.85e-02, acc = 9.57e-01 (0.01s)
# [VAL] epoch = 216, data_cost = 8.04e-01, cost = 1.06e+00, acc = 7.96e-01 (0.00s)
# [TST] epoch = 216, cost = 1.00e+00, acc = 8.06e-01 (0.00s)
# [TRN] epoch = 217, cost = 5.76e-01, |grad| = 4.30e-02, acc = 9.79e-01 (0.01s)
# [VAL] epoch = 217, data_cost = 8.05e-01, cost = 1.06e+00, acc = 7.98e-01 (0.00s)
# [TST] epoch = 217, cost = 1.00e+00, acc = 8.06e-01 (0.00s)
# [TRN] epoch = 218, cost = 5.58e-01, |grad| = 4.22e-02, acc = 9.79e-01 (0.01s)
# [VAL] epoch = 218, data_cost = 8.06e-01, cost = 1.06e+00, acc = 7.96e-01 (0.00s)
# [TST] epoch = 218, cost = 1.01e+00, acc = 8.06e-01 (0.00s)
# [TRN] epoch = 219, cost = 5.94e-01, |grad| = 4.24e-02, acc = 9.57e-01 (0.01s)
# [VAL] epoch = 219, data_cost = 8.06e-01, cost = 1.06e+00, acc = 7.94e-01 (0.00s)
# [TST] epoch = 219, cost = 1.01e+00, acc = 8.05e-01 (0.00s)
# [TRN] epoch = 220, cost = 5.46e-01, |grad| = 3.88e-02, acc = 9.86e-01 (0.01s)
# ...
# [TRN] epoch = 319, cost = 4.99e-01, |grad| = 3.68e-02, acc = 9.79e-01 (0.01s)
# [VAL] epoch = 319, data_cost = 7.44e-01, cost = 9.67e-01, acc = 7.90e-01 (0.00s)
# [TST] epoch = 319, cost = 9.14e-01, acc = 8.17e-01 (0.00s)
# [TRN] epoch = 320, cost = 4.82e-01, |grad| = 3.46e-02, acc = 9.79e-01 (0.01s)
# [VAL] epoch = 320, data_cost = 7.44e-01, cost = 9.66e-01, acc = 7.88e-01 (0.01s)
# [TST] epoch = 320, cost = 9.14e-01, acc = 8.16e-01 (0.00s)
# [TRN] epoch = 321, cost = 4.83e-01, |grad| = 3.66e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 321, data_cost = 7.43e-01, cost = 9.64e-01, acc = 7.88e-01 (0.00s)
# [TST] epoch = 321, cost = 9.12e-01, acc = 8.16e-01 (0.01s)
# [TRN] epoch = 322, cost = 5.17e-01, |grad| = 3.97e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 322, data_cost = 7.42e-01, cost = 9.64e-01, acc = 7.88e-01 (0.00s)
# [TST] epoch = 322, cost = 9.11e-01, acc = 8.16e-01 (0.00s)
# [TRN] epoch = 323, cost = 5.26e-01, |grad| = 4.80e-02, acc = 9.71e-01 (0.01s)
# [VAL] epoch = 323, data_cost = 7.42e-01, cost = 9.64e-01, acc = 7.92e-01 (0.01s)
# [TST] epoch = 323, cost = 9.11e-01, acc = 8.16e-01 (0.00s)
# [TRN] epoch = 324, cost = 4.83e-01, |grad| = 3.98e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 324, data_cost = 7.43e-01, cost = 9.64e-01, acc = 7.92e-01 (0.00s)
# [TST] epoch = 324, cost = 9.11e-01, acc = 8.17e-01 (0.00s)
# [TRN] epoch = 325, cost = 4.82e-01, |grad| = 4.01e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 325, data_cost = 7.43e-01, cost = 9.64e-01, acc = 7.94e-01 (0.01s)
# [TST] epoch = 325, cost = 9.11e-01, acc = 8.16e-01 (0.00s)
# [TRN] epoch = 326, cost = 4.84e-01, |grad| = 3.52e-02, acc = 1.00e+00 (0.01s)
# [VAL] epoch = 326, data_cost = 7.43e-01, cost = 9.64e-01, acc = 7.96e-01 (0.00s)
# [TST] epoch = 326, cost = 9.10e-01, acc = 8.16e-01 (0.00s)
# [TRN] epoch = 327, cost = 5.06e-01, |grad| = 4.48e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 327, data_cost = 7.43e-01, cost = 9.65e-01, acc = 7.88e-01 (0.00s)
# [TST] epoch = 327, cost = 9.11e-01, acc = 8.17e-01 (0.00s)
# [TRN] epoch = 328, cost = 4.79e-01, |grad| = 3.58e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 328, data_cost = 7.44e-01, cost = 9.66e-01, acc = 7.90e-01 (0.00s)
# [TST] epoch = 328, cost = 9.11e-01, acc = 8.19e-01 (0.00s)
# [TRN] epoch = 329, cost = 4.36e-01, |grad| = 3.46e-02, acc = 9.79e-01 (0.01s)
# [VAL] epoch = 329, data_cost = 7.45e-01, cost = 9.66e-01, acc = 7.92e-01 (0.00s)
# [TST] epoch = 329, cost = 9.12e-01, acc = 8.18e-01 (0.00s)
# [TRN] epoch = 330, cost = 5.30e-01, |grad| = 5.14e-02, acc = 9.71e-01 (0.01s)
# [VAL] epoch = 330, data_cost = 7.46e-01, cost = 9.67e-01, acc = 7.90e-01 (0.00s)
# [TST] epoch = 330, cost = 9.13e-01, acc = 8.18e-01 (0.00s)
# [TRN] epoch = 331, cost = 4.73e-01, |grad| = 3.95e-02, acc = 9.86e-01 (0.01s)
# [VAL] epoch = 331, data_cost = 7.47e-01, cost = 9.68e-01, acc = 7.92e-01 (0.00s)
# [TST] epoch = 331, cost = 9.13e-01, acc = 8.14e-01 (0.00s)
# [TRN] epoch = 332, cost = 4.43e-01, |grad| = 3.89e-02, acc = 9.79e-01 (0.01s)
# [VAL] epoch = 332, data_cost = 7.48e-01, cost = 9.69e-01, acc = 7.92e-01 (0.00s)
# [TST] epoch = 332, cost = 9.14e-01, acc = 8.14e-01 (0.00s)
# [TRN] epoch = 333, cost = 4.57e-01, |grad| = 3.65e-02, acc = 9.93e-01 (0.01s)
# [VAL] epoch = 333, data_cost = 7.48e-01, cost = 9.69e-01, acc = 7.92e-01 (0.00s)
# [TST] epoch = 333, cost = 9.14e-01, acc = 8.15e-01 (0.01s)
# [TRN] epoch = 334, cost = 4.99e-01, |grad| = 4.24e-02, acc = 9.57e-01 (0.01s)
# [VAL] epoch = 334, data_cost = 7.47e-01, cost = 9.68e-01, acc = 7.92e-01 (0.00s)
# [TST] epoch = 334, cost = 9.13e-01, acc = 8.16e-01 (0.00s)
# [TRN] epoch = 335, cost = 4.53e-01, |grad| = 3.52e-02, acc = 9.79e-01 (0.01s)
# [VAL] epoch = 335, data_cost = 7.47e-01, cost = 9.67e-01, acc = 7.90e-01 (0.00s)
# [TST] epoch = 335, cost = 9.12e-01, acc = 8.17e-01 (0.00s)
# [TRN] epoch = 336, cost = 5.22e-01, |grad| = 4.30e-02, acc = 9.79e-01 (0.01s)
# [VAL] epoch = 336, data_cost = 7.46e-01, cost = 9.67e-01, acc = 7.90e-01 (0.00s)
# [TST] epoch = 336, cost = 9.11e-01, acc = 8.17e-01 (0.01s)
# [TRN] epoch = 337, cost = 4.71e-01, |grad| = 3.69e-02, acc = 9.57e-01 (0.01s)
# [VAL] epoch = 337, data_cost = 7.45e-01, cost = 9.65e-01, acc = 7.88e-01 (0.00s)
# [TST] epoch = 337, cost = 9.10e-01, acc = 8.17e-01 (0.00s)
# [TRN] epoch = 338, cost = 4.67e-01, |grad| = 3.64e-02, acc = 9.79e-01 (0.01s)
# [VAL] epoch = 338, data_cost = 7.43e-01, cost = 9.63e-01, acc = 7.86e-01 (0.01s)
# [TST] epoch = 338, cost = 9.08e-01, acc = 8.17e-01 (0.01s)
# [TRN] epoch = 339, cost = 5.05e-01, |grad| = 3.73e-02, acc = 9.71e-01 (0.01s)
# [VAL] epoch = 339, data_cost = 7.41e-01, cost = 9.61e-01, acc = 7.86e-01 (0.00s)
# [TST] epoch = 339, cost = 9.06e-01, acc = 8.14e-01 (0.00s)
# [TRN] epoch = 340, cost = 4.58e-01, |grad| = 3.91e-02, acc = 9.79e-01 (0.01s)
# [VAL] epoch = 340, data_cost = 7.39e-01, cost = 9.59e-01, acc = 7.88e-01 (0.00s)
# [TST] epoch = 340, cost = 9.05e-01, acc = 8.15e-01 (0.00s)
# [TRN] epoch = 341, cost = 4.79e-01, |grad| = 4.19e-02, acc = 9.79e-01 (0.01s)
# [VAL] epoch = 341, data_cost = 7.37e-01, cost = 9.57e-01, acc = 7.90e-01 (0.00s)
# [TST] epoch = 341, cost = 9.03e-01, acc = 8.15e-01 (0.01s)
# [TRN] epoch = 342, cost = 4.73e-01, |grad| = 3.99e-02, acc = 9.79e-01 (0.01s)
# [VAL] epoch = 342, data_cost = 7.35e-01, cost = 9.55e-01, acc = 7.90e-01 (0.00s)
# [TST] epoch = 342, cost = 9.01e-01, acc = 8.15e-01 (0.00s)
# [TRN] epoch = 343, cost = 4.98e-01, |grad| = 5.19e-02, acc = 9.57e-01 (0.01s)
# [VAL] epoch = 343, data_cost = 7.35e-01, cost = 9.54e-01, acc = 7.90e-01 (0.00s)
# [TST] epoch = 343, cost = 9.01e-01, acc = 8.17e-01 (0.00s)
# [TRN] epoch = 344, cost = 4.83e-01, |grad| = 3.74e-02, acc = 9.79e-01 (0.01s)
# [VAL] epoch = 344, data_cost = 7.35e-01, cost = 9.54e-01, acc = 7.92e-01 (0.00s)
# [TST] epoch = 344, cost = 9.00e-01, acc = 8.17e-01 (0.00s)
# [TRN] epoch = 345, cost = 5.11e-01, |grad| = 5.09e-02, acc = 9.50e-01 (0.01s)
# [VAL] epoch = 345, data_cost = 7.35e-01, cost = 9.54e-01, acc = 7.92e-01 (0.00s)
# [TST] epoch = 345, cost = 9.01e-01, acc = 8.14e-01 (0.00s)
# [TRN] epoch = 346, cost = 5.03e-01, |grad| = 4.34e-02, acc = 9.71e-01 (0.01s)
# [VAL] epoch = 346, data_cost = 7.38e-01, cost = 9.57e-01, acc = 7.92e-01 (0.01s)
# [TST] epoch = 346, cost = 9.03e-01, acc = 8.14e-01 (0.00s)
# [TRN] epoch = 347, cost = 4.89e-01, |grad| = 3.81e-02, acc = 9.86e-01 (0.01s)
# [VAL] epoch = 347, data_cost = 7.39e-01, cost = 9.58e-01, acc = 7.92e-01 (0.00s)
# [TST] epoch = 347, cost = 9.05e-01, acc = 8.13e-01 (0.00s)
# [TRN] epoch = 348, cost = 4.50e-01, |grad| = 3.81e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 348, data_cost = 7.42e-01, cost = 9.60e-01, acc = 7.92e-01 (0.00s)
# [TST] epoch = 348, cost = 9.06e-01, acc = 8.13e-01 (0.00s)
# [TRN] epoch = 349, cost = 4.90e-01, |grad| = 3.88e-02, acc = 9.71e-01 (0.01s)
# [VAL] epoch = 349, data_cost = 7.44e-01, cost = 9.63e-01, acc = 7.90e-01 (0.00s)
# [TST] epoch = 349, cost = 9.09e-01, acc = 8.14e-01 (0.01s)
# [TRN] epoch = 350, cost = 4.53e-01, |grad| = 3.54e-02, acc = 9.71e-01 (0.01s)
# [VAL] epoch = 350, data_cost = 7.48e-01, cost = 9.66e-01, acc = 7.90e-01 (0.00s)
# [TST] epoch = 350, cost = 9.11e-01, acc = 8.14e-01 (0.00s)
# [TRN] epoch = 351, cost = 4.40e-01, |grad| = 3.47e-02, acc = 9.79e-01 (0.01s)
# [VAL] epoch = 351, data_cost = 7.50e-01, cost = 9.69e-01, acc = 7.92e-01 (0.00s)
# [TST] epoch = 351, cost = 9.13e-01, acc = 8.13e-01 (0.01s)
# [TRN] epoch = 352, cost = 4.61e-01, |grad| = 3.44e-02, acc = 9.79e-01 (0.01s)
# [VAL] epoch = 352, data_cost = 7.52e-01, cost = 9.70e-01, acc = 7.96e-01 (0.00s)
# [TST] epoch = 352, cost = 9.14e-01, acc = 8.13e-01 (0.00s)
# [TRN] epoch = 353, cost = 5.08e-01, |grad| = 6.70e-02, acc = 9.71e-01 (0.01s)
# [VAL] epoch = 353, data_cost = 7.53e-01, cost = 9.71e-01, acc = 7.92e-01 (0.00s)
# [TST] epoch = 353, cost = 9.15e-01, acc = 8.13e-01 (0.00s)
# [TRN] epoch = 354, cost = 4.40e-01, |grad| = 3.76e-02, acc = 9.71e-01 (0.01s)
# [VAL] epoch = 354, data_cost = 7.52e-01, cost = 9.70e-01, acc = 7.92e-01 (0.00s)
# [TST] epoch = 354, cost = 9.14e-01, acc = 8.14e-01 (0.01s)
# [TRN] epoch = 355, cost = 4.62e-01, |grad| = 4.07e-02, acc = 9.79e-01 (0.01s)
# [VAL] epoch = 355, data_cost = 7.51e-01, cost = 9.68e-01, acc = 7.94e-01 (0.00s)
# [TST] epoch = 355, cost = 9.12e-01, acc = 8.13e-01 (0.00s)
# [TRN] epoch = 356, cost = 4.97e-01, |grad| = 4.33e-02, acc = 9.79e-01 (0.01s)
# [VAL] epoch = 356, data_cost = 7.48e-01, cost = 9.65e-01, acc = 7.92e-01 (0.00s)
# [TST] epoch = 356, cost = 9.09e-01, acc = 8.13e-01 (0.01s)
# [TRN] epoch = 357, cost = 5.01e-01, |grad| = 4.65e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 357, data_cost = 7.45e-01, cost = 9.62e-01, acc = 7.94e-01 (0.00s)
# [TST] epoch = 357, cost = 9.06e-01, acc = 8.16e-01 (0.00s)
# [TRN] epoch = 358, cost = 4.16e-01, |grad| = 3.24e-02, acc = 9.93e-01 (0.01s)
# [VAL] epoch = 358, data_cost = 7.42e-01, cost = 9.58e-01, acc = 7.94e-01 (0.00s)
# [TST] epoch = 358, cost = 9.03e-01, acc = 8.15e-01 (0.00s)
# [TRN] epoch = 359, cost = 4.72e-01, |grad| = 3.70e-02, acc = 9.71e-01 (0.01s)
# [VAL] epoch = 359, data_cost = 7.40e-01, cost = 9.56e-01, acc = 7.92e-01 (0.00s)
# [TST] epoch = 359, cost = 9.01e-01, acc = 8.18e-01 (0.00s)
# [TRN] epoch = 360, cost = 4.57e-01, |grad| = 3.96e-02, acc = 9.93e-01 (0.01s)
# [VAL] epoch = 360, data_cost = 7.39e-01, cost = 9.55e-01, acc = 7.94e-01 (0.00s)
# [TST] epoch = 360, cost = 8.99e-01, acc = 8.18e-01 (0.01s)
# [TRN] epoch = 361, cost = 4.75e-01, |grad| = 3.83e-02, acc = 9.93e-01 (0.01s)
# [VAL] epoch = 361, data_cost = 7.37e-01, cost = 9.53e-01, acc = 7.94e-01 (0.00s)
# [TST] epoch = 361, cost = 8.97e-01, acc = 8.18e-01 (0.01s)
# [TRN] epoch = 362, cost = 5.11e-01, |grad| = 3.95e-02, acc = 9.71e-01 (0.01s)
# [VAL] epoch = 362, data_cost = 7.36e-01, cost = 9.52e-01, acc = 7.96e-01 (0.00s)
# [TST] epoch = 362, cost = 8.96e-01, acc = 8.18e-01 (0.00s)
# [TRN] epoch = 363, cost = 4.78e-01, |grad| = 3.78e-02, acc = 9.79e-01 (0.01s)
# [VAL] epoch = 363, data_cost = 7.34e-01, cost = 9.50e-01, acc = 7.92e-01 (0.00s)
# [TST] epoch = 363, cost = 8.95e-01, acc = 8.19e-01 (0.00s)
# [TRN] epoch = 364, cost = 4.69e-01, |grad| = 3.80e-02, acc = 9.79e-01 (0.01s)
# [VAL] epoch = 364, data_cost = 7.34e-01, cost = 9.50e-01, acc = 7.92e-01 (0.00s)
# [TST] epoch = 364, cost = 8.94e-01, acc = 8.20e-01 (0.00s)
# [TRN] epoch = 365, cost = 4.20e-01, |grad| = 3.71e-02, acc = 9.79e-01 (0.01s)
# [VAL] epoch = 365, data_cost = 7.33e-01, cost = 9.48e-01, acc = 7.92e-01 (0.00s)
# [TST] epoch = 365, cost = 8.93e-01, acc = 8.21e-01 (0.00s)
# [TRN] epoch = 366, cost = 4.94e-01, |grad| = 4.15e-02, acc = 9.71e-01 (0.01s)
# [VAL] epoch = 366, data_cost = 7.31e-01, cost = 9.47e-01, acc = 7.92e-01 (0.00s)
# [TST] epoch = 366, cost = 8.91e-01, acc = 8.22e-01 (0.00s)
# [TRN] epoch = 367, cost = 4.78e-01, |grad| = 3.97e-02, acc = 9.79e-01 (0.01s)
# [VAL] epoch = 367, data_cost = 7.31e-01, cost = 9.46e-01, acc = 7.92e-01 (0.00s)
# [TST] epoch = 367, cost = 8.91e-01, acc = 8.23e-01 (0.00s)
# [TRN] epoch = 368, cost = 4.40e-01, |grad| = 4.08e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 368, data_cost = 7.31e-01, cost = 9.46e-01, acc = 7.92e-01 (0.00s)
# [TST] epoch = 368, cost = 8.90e-01, acc = 8.22e-01 (0.00s)
# [TRN] epoch = 369, cost = 4.76e-01, |grad| = 3.90e-02, acc = 9.57e-01 (0.01s)
# [VAL] epoch = 369, data_cost = 7.31e-01, cost = 9.46e-01, acc = 7.96e-01 (0.00s)
# [TST] epoch = 369, cost = 8.91e-01, acc = 8.22e-01 (0.00s)
# [TRN] epoch = 370, cost = 4.53e-01, |grad| = 3.88e-02, acc = 9.79e-01 (0.01s)
# [VAL] epoch = 370, data_cost = 7.33e-01, cost = 9.47e-01, acc = 7.96e-01 (0.00s)
# [TST] epoch = 370, cost = 8.92e-01, acc = 8.19e-01 (0.00s)
# [TRN] epoch = 371, cost = 4.42e-01, |grad| = 3.23e-02, acc = 9.79e-01 (0.01s)
# [VAL] epoch = 371, data_cost = 7.35e-01, cost = 9.49e-01, acc = 7.94e-01 (0.00s)
# [TST] epoch = 371, cost = 8.93e-01, acc = 8.18e-01 (0.00s)
# [TRN] epoch = 372, cost = 4.40e-01, |grad| = 3.67e-02, acc = 9.93e-01 (0.01s)
# [VAL] epoch = 372, data_cost = 7.37e-01, cost = 9.51e-01, acc = 7.94e-01 (0.00s)
# [TST] epoch = 372, cost = 8.94e-01, acc = 8.18e-01 (0.00s)
# [TRN] epoch = 373, cost = 4.06e-01, |grad| = 3.32e-02, acc = 1.00e+00 (0.01s)
# [VAL] epoch = 373, data_cost = 7.39e-01, cost = 9.52e-01, acc = 7.94e-01 (0.00s)
# [TST] epoch = 373, cost = 8.95e-01, acc = 8.19e-01 (0.00s)
# [TRN] epoch = 374, cost = 4.46e-01, |grad| = 4.12e-02, acc = 9.71e-01 (0.01s)
# [VAL] epoch = 374, data_cost = 7.40e-01, cost = 9.54e-01, acc = 7.90e-01 (0.00s)
# [TST] epoch = 374, cost = 8.97e-01, acc = 8.17e-01 (0.00s)
# [TRN] epoch = 375, cost = 4.36e-01, |grad| = 3.47e-02, acc = 1.00e+00 (0.01s)
# [VAL] epoch = 375, data_cost = 7.40e-01, cost = 9.53e-01, acc = 7.92e-01 (0.00s)
# [TST] epoch = 375, cost = 8.96e-01, acc = 8.18e-01 (0.00s)
# [TRN] epoch = 376, cost = 4.64e-01, |grad| = 4.31e-02, acc = 9.93e-01 (0.01s)
# [VAL] epoch = 376, data_cost = 7.39e-01, cost = 9.52e-01, acc = 7.92e-01 (0.01s)
# [TST] epoch = 376, cost = 8.95e-01, acc = 8.18e-01 (0.00s)
# [TRN] epoch = 377, cost = 4.23e-01, |grad| = 3.32e-02, acc = 1.00e+00 (0.01s)
# [VAL] epoch = 377, data_cost = 7.37e-01, cost = 9.49e-01, acc = 7.92e-01 (0.00s)
# [TST] epoch = 377, cost = 8.93e-01, acc = 8.17e-01 (0.00s)
# [TRN] epoch = 378, cost = 4.47e-01, |grad| = 4.47e-02, acc = 9.79e-01 (0.01s)
# [VAL] epoch = 378, data_cost = 7.33e-01, cost = 9.45e-01, acc = 7.94e-01 (0.01s)
# [TST] epoch = 378, cost = 8.89e-01, acc = 8.17e-01 (0.00s)
# [TRN] epoch = 379, cost = 5.07e-01, |grad| = 4.47e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 379, data_cost = 7.30e-01, cost = 9.41e-01, acc = 7.96e-01 (0.00s)
# [TST] epoch = 379, cost = 8.86e-01, acc = 8.16e-01 (0.01s)
# [TRN] epoch = 380, cost = 4.64e-01, |grad| = 4.20e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 380, data_cost = 7.26e-01, cost = 9.37e-01, acc = 7.96e-01 (0.00s)
# [TST] epoch = 380, cost = 8.83e-01, acc = 8.16e-01 (0.00s)
# [TRN] epoch = 381, cost = 4.36e-01, |grad| = 3.67e-02, acc = 9.93e-01 (0.01s)
# [VAL] epoch = 381, data_cost = 7.23e-01, cost = 9.34e-01, acc = 8.00e-01 (0.00s)
# [TST] epoch = 381, cost = 8.80e-01, acc = 8.22e-01 (0.00s)
# [TRN] epoch = 382, cost = 4.37e-01, |grad| = 3.62e-02, acc = 9.86e-01 (0.01s)
# [VAL] epoch = 382, data_cost = 7.22e-01, cost = 9.33e-01, acc = 7.94e-01 (0.00s)
# [TST] epoch = 382, cost = 8.79e-01, acc = 8.22e-01 (0.00s)
# [TRN] epoch = 383, cost = 4.31e-01, |grad| = 3.31e-02, acc = 9.86e-01 (0.01s)
# [VAL] epoch = 383, data_cost = 7.21e-01, cost = 9.31e-01, acc = 7.92e-01 (0.01s)
# [TST] epoch = 383, cost = 8.77e-01, acc = 8.22e-01 (0.00s)
# [TRN] epoch = 384, cost = 4.24e-01, |grad| = 3.45e-02, acc = 9.93e-01 (0.01s)
# [VAL] epoch = 384, data_cost = 7.20e-01, cost = 9.30e-01, acc = 7.92e-01 (0.00s)
# [TST] epoch = 384, cost = 8.77e-01, acc = 8.23e-01 (0.00s)
# [TRN] epoch = 385, cost = 4.05e-01, |grad| = 3.27e-02, acc = 9.86e-01 (0.01s)
# [VAL] epoch = 385, data_cost = 7.21e-01, cost = 9.30e-01, acc = 7.92e-01 (0.00s)
# [TST] epoch = 385, cost = 8.76e-01, acc = 8.23e-01 (0.00s)
# [TRN] epoch = 386, cost = 4.39e-01, |grad| = 3.35e-02, acc = 9.86e-01 (0.01s)
# [VAL] epoch = 386, data_cost = 7.22e-01, cost = 9.31e-01, acc = 7.94e-01 (0.00s)
# [TST] epoch = 386, cost = 8.77e-01, acc = 8.26e-01 (0.00s)
# [TRN] epoch = 387, cost = 4.05e-01, |grad| = 3.49e-02, acc = 9.93e-01 (0.01s)
# [VAL] epoch = 387, data_cost = 7.23e-01, cost = 9.32e-01, acc = 7.94e-01 (0.00s)
# [TST] epoch = 387, cost = 8.77e-01, acc = 8.25e-01 (0.00s)
# [TRN] epoch = 388, cost = 4.33e-01, |grad| = 3.58e-02, acc = 9.86e-01 (0.01s)
# [VAL] epoch = 388, data_cost = 7.26e-01, cost = 9.34e-01, acc = 7.92e-01 (0.00s)
# [TST] epoch = 388, cost = 8.79e-01, acc = 8.25e-01 (0.00s)
# [TRN] epoch = 389, cost = 4.37e-01, |grad| = 3.81e-02, acc = 9.79e-01 (0.01s)
# [VAL] epoch = 389, data_cost = 7.29e-01, cost = 9.36e-01, acc = 7.92e-01 (0.00s)
# [TST] epoch = 389, cost = 8.81e-01, acc = 8.24e-01 (0.00s)
# [TRN] epoch = 390, cost = 4.52e-01, |grad| = 4.32e-02, acc = 9.71e-01 (0.01s)
# [VAL] epoch = 390, data_cost = 7.31e-01, cost = 9.38e-01, acc = 7.88e-01 (0.00s)
# [TST] epoch = 390, cost = 8.82e-01, acc = 8.22e-01 (0.00s)
# [TRN] epoch = 391, cost = 4.88e-01, |grad| = 3.71e-02, acc = 9.64e-01 (0.01s)
# [VAL] epoch = 391, data_cost = 7.34e-01, cost = 9.41e-01, acc = 7.84e-01 (0.00s)
# [TST] epoch = 391, cost = 8.84e-01, acc = 8.19e-01 (0.00s)
# [TRN] epoch = 392, cost = 4.39e-01, |grad| = 4.62e-02, acc = 9.64e-01 (0.01s)

# %%
#Print average performance
print(np.mean(list_all_acc))
print(np.std(list_all_acc))
# Out:
# 81.979996
# 0.48538783
